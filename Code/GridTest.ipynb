# %% [markdown]
# All tests for part (d),

# %%
def get_activation(name):
    if isinstance(name, nn.Module):
        return name
    name = name.lower()
    if name == "tanh":
        return nn.Tanh()
    if name == "relu":
        return nn.ReLU()
    if name == "sigmoid":
        return nn.Sigmoid()
    if name == "gelu":
        return nn.GELU()
    if name == "elu":
        return nn.ELU
    if name == "leaky":
        return nn.LeakyReLU
    raise ValueError(f"Unknown activation: {name}")

class PINN(nn.Module):
    """
    PINN for u_t = u_xx on x in [0,1], t in [0,T],
    with u(x,0) = sin(pi x), u(0,t) = u(1,t) = 0.

    Trial solution:
        g(x,t) = (1 - t) sin(pi x) + x (1 - x) t N_theta(x,t)
    """

    def __init__(self, layers, activation="tanh", device=None):
        super().__init__()

        if device is None:
            device = "cuda" if torch.cuda.is_available() else "cpu"
        self.device = torch.device(device)

        act = get_activation(activation)

        modules = []
        for in_dim, out_dim in zip(layers[:-2], layers[1:-1]):
            modules.append(nn.Linear(in_dim, out_dim))
            modules.append(act)
        modules.append(nn.Linear(layers[-2], layers[-1]))
        self.net = nn.Sequential(*modules)

        self.to(self.device)

    # Raw network N_theta(x,t)
    def network(self, x, t):
        inp = torch.cat([x, t], dim=1)  # (N,2)
        return self.net(inp)            # (N,1)

    # Initial condition u(x,0) = sin(pi x)
    def u0(self, x):
        return torch.sin(torch.pi * x)

    # Trial solution g(x,t)
    def trial_solution(self, x, t):
        N = self.network(x, t)
        return (1.0 - t) * self.u0(x) + x * (1.0 - x) * t * N

    # Right-hand side f(x,t) = 0 here
    def f(self, x, t):
        return torch.zeros_like(x)

    # PDE residual r = g_t - g_xx - f
    def residual(self, x, t):
        x = x.clone().detach().to(self.device).requires_grad_(True)
        t = t.clone().detach().to(self.device).requires_grad_(True)

        g = self.trial_solution(x, t)

        g_t = torch.autograd.grad(
            g, t,
            grad_outputs=torch.ones_like(g),
            create_graph=True,
            retain_graph=True,
        )[0]

        g_x = torch.autograd.grad(
            g, x,
            grad_outputs=torch.ones_like(g),
            create_graph=True,
            retain_graph=True,
        )[0]

        g_xx = torch.autograd.grad(
            g_x, x,
            grad_outputs=torch.ones_like(g_x),
            create_graph=True,
            retain_graph=True,
        )[0]

        r = g_t - g_xx - self.f(x, t)
        return r

    def loss(self, x_coll, t_coll):
        r = self.residual(x_coll, t_coll)
        return torch.mean(r**2)

    def train_pinn(self, x_coll, t_coll,
                   epochs=5000, lr=1e-3,
                   optimizer_cls=optim.Adam,
                   verbose_every=500):
        x_coll = x_coll.reshape(-1, 1).to(self.device)
        t_coll = t_coll.reshape(-1, 1).to(self.device)

        optimizer = optimizer_cls(self.parameters(), lr=lr)

        for epoch in range(epochs):
            optimizer.zero_grad()
            loss = self.loss(x_coll, t_coll)
            loss.backward()
            optimizer.step()

            if verbose_every and epoch % verbose_every == 0:
                print(f"Epoch {epoch:5d} | Loss = {loss.item():.3e}")

        return self
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 19
#      16         return nn.LeakyReLU
#      17     raise ValueError(f"Unknown activation: {name}")
# ---> 19 class PINN(nn.Module):
#      20     """
#      21     PINN for u_t = u_xx on x in [0,1], t in [0,T],
#      22     with u(x,0) = sin(pi x), u(0,t) = u(1,t) = 0.
#    (...)
#      25         g(x,t) = (1 - t) sin(pi x) + x (1 - x) t N_theta(x,t)
#      26     """
#      28     def __init__(self, layers, activation="tanh", device=None):
#
# NameError: name 'nn' is not defined

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt


# ---------- Helper: activation chooser ----------

def get_activation(name):
    """
    Return a PyTorch activation module given a name or module.

    Parameters
    ----------
    name : str or nn.Module
        Name of the activation ("tanh", "relu", "sigmoid", "gelu") or a
        pre-instantiated torch.nn.Module.

    Returns
    -------
    nn.Module
        Activation function module.
    """
    if isinstance(name, nn.Module):
        return name
    name = name.lower()
    if name == "elu":
        return nn.ELU()
    if name == "tanh":
        return nn.Tanh()
    if name == "relu":
        return nn.ReLU()
    if name == "sigmoid":
        return nn.Sigmoid()
    if name == "gelu":
        return nn.GELU()
    raise ValueError(f"Unknown activation: {name}")


# ---------- PINN class (CPU-only, Jensen-style trial solution) ----------

class PINN(nn.Module):
    """
    PINN for the 1D heat equation

        u_t = u_xx,  x in [0,1],  t in [0,T],

    with u(x,0) = sin(pi x), u(0,t) = u(1,t) = 0.

    Trial solution:
        g(x,t) = (1 - t) sin(pi x) + x (1 - x) t N_θ(x,t),
    where N_θ is a fully-connected neural network.
    """

    def __init__(self, layers, activation="tanh"):
        """
        Initialize the PINN model.

        Parameters
        ----------
        layers : list[int]
            Layer sizes, e.g. [2, 20, 20, 1].
        activation : str or nn.Module, default "tanh"
            Activation function for hidden layers.
        """
        super().__init__()

        act = get_activation(activation)

        modules = []
        for in_dim, out_dim in zip(layers[:-2], layers[1:-1]):
            modules.append(nn.Linear(in_dim, out_dim))
            modules.append(act)
        modules.append(nn.Linear(layers[-2], layers[-1]))
        self.net = nn.Sequential(*modules)

    def network(self, x, t):
        """
        Raw network N_θ(x,t).

        Parameters
        ----------
        x, t : torch.Tensor of shape (N,1)

        Returns
        -------
        torch.Tensor of shape (N,1)
        """
        inp = torch.cat([x, t], dim=1)
        return self.net(inp)

    def u0(self, x):
        """
        Initial condition u(x,0) = sin(pi x).
        """
        return torch.sin(torch.pi * x)

    def trial_solution(self, x, t):
        """
        Trial solution g(x,t) that satisfies IC and BC.

        g(x,t) = (1 - t) u0(x) + x (1 - x) t N_θ(x,t)
        """
        N = self.network(x, t)
        return (1.0 - t) * self.u0(x) + x * (1.0 - x) * t * N

    def f(self, x, t):
        """
        Right-hand side f(x,t) in u_t = u_xx + f. Here f = 0.
        """
        return torch.zeros_like(x)

    def residual(self, x, t):
        """
        PDE residual r(x,t) = g_t - g_xx - f at collocation points.

        Parameters
        ----------
        x, t : torch.Tensor of shape (N,1)

        Returns
        -------
        torch.Tensor of shape (N,1)
        """
        x = x.clone().detach().requires_grad_(True)
        t = t.clone().detach().requires_grad_(True)

        g = self.trial_solution(x, t)

        g_t = torch.autograd.grad(
            g, t,
            grad_outputs=torch.ones_like(g),
            create_graph=True,
            retain_graph=True,
        )[0]

        g_x = torch.autograd.grad(
            g, x,
            grad_outputs=torch.ones_like(g),
            create_graph=True,
            retain_graph=True,
        )[0]

        g_xx = torch.autograd.grad(
            g_x, x,
            grad_outputs=torch.ones_like(g_x),
            create_graph=True,
            retain_graph=True,
        )[0]

        r = g_t - g_xx - self.f(x, t)
        return r

    def loss(self, x_coll, t_coll):
        """
        Mean squared PDE residual over collocation points.
        """
        r = self.residual(x_coll, t_coll)
        return torch.mean(r**2)

    def train_pinn(self, x_coll, t_coll,
                   epochs=2000, lr=1e-3,
                   optimizer_cls=optim.Adam,
                   verbose_every=0):
        """
        Train the PINN on given collocation points.

        Parameters
        ----------
        x_coll, t_coll : torch.Tensor of shape (N,) or (N,1)
        epochs : int, default 2000
        lr : float, default 1e-3
        optimizer_cls : optimizer class, default Adam
        verbose_every : int, default 0
            If > 0, print loss every verbose_every epochs.
        """
        x_coll = x_coll.reshape(-1, 1)
        t_coll = t_coll.reshape(-1, 1)

        optimizer = optimizer_cls(self.parameters(), lr=lr)

        for epoch in range(epochs):
            optimizer.zero_grad()
            loss = self.loss(x_coll, t_coll)
            loss.backward()
            optimizer.step()

            if verbose_every and epoch % verbose_every == 0:
                print(f"Epoch {epoch:5d} | Loss = {loss.item():.3e}")

        return self


# ---------- Collocation + analytical solution ----------

def make_collocation(Nx=40, Nt=40, T=0.3):
    """
    Uniform collocation points on [0,1] × [0,T].
    """
    x = torch.linspace(0.0, 1.0, Nx)
    t = torch.linspace(0.0, T, Nt)
    X, Tm = torch.meshgrid(x, t, indexing="ij")
    x_coll = X.reshape(-1, 1)
    t_coll = Tm.reshape(-1, 1)
    return x_coll, t_coll


def analytical_u(x, t_scalar):
    """
    Analytical solution for u_t = u_xx with u(x,0) = sin(pi x):

        u(x,t) = exp(-pi^2 t) sin(pi x).
    """
    if isinstance(x, torch.Tensor):
        x_np = x.detach().cpu().numpy().flatten()
    else:
        x_np = np.asarray(x).flatten()
    return np.exp(-np.pi**2 * t_scalar) * np.sin(np.pi * x_np)


# ---------- Sweep over activations / depths / widths ----------

def run_architecture_sweep():
    """
    Train many PINNs with different (activation, depth, width) and
    plot only the resulting MSE values in a bar chart.
    """
    # where to evaluate MSE
    t_eval = 0.1

    # collocation grid
    x_coll, t_coll = make_collocation(Nx=40, Nt=40, T=0.3)

    # test grid at fixed time
    x_test = torch.linspace(0, 1, 200).reshape(-1, 1)

    # architecture / activation choices
    activations = ["tanh", "relu", "sigmoid", "gelu"]
    depths = [1, 2, 3]       # number of hidden layers
    widths = [10, 20, 50]    # neurons per hidden layer

    results = []  # list of dicts: { "label", "activation", "depth", "width", "mse" }

    for act in activations:
        for depth in depths:
            for width in widths:
                layers = [2] + [width] * depth + [1]
                label = f"{act}-L{depth}-W{width}"
                print(f"\n=== Training {label} ===")

                model = PINN(layers=layers, activation=act)
                model.train_pinn(x_coll, t_coll,
                                 epochs=2000, lr=1e-3,
                                 optimizer_cls=optim.Adam,
                                 verbose_every=0)

                with torch.no_grad():
                    t_test = torch.full_like(x_test, t_eval)
                    u_pinn = model.trial_solution(x_test, t_test).cpu().numpy().flatten()

                u_exact = analytical_u(x_test, t_eval)
                mse = np.mean((u_pinn - u_exact)**2)
                print(f"{label}: MSE = {mse:.3e}")

                results.append({
                    "label": label,
                    "activation": act,
                    "depth": depth,
                    "width": width,
                    "mse": mse
                })

    # ---------- Plot MSE only ----------

    # Make a separate bar plot per activation for clarity
    for act in activations:
        sub = [r for r in results if r["activation"] == act]
        if not sub:
            continue

        labels = [f"L{r['depth']}-W{r['width']}" for r in sub]
        mses = [r["mse"] for r in sub]

        x_pos = np.arange(len(sub))

        plt.figure(figsize=(8, 4))
        plt.bar(x_pos, mses)
        plt.xticks(x_pos, labels, rotation=45, ha="right")
        plt.ylabel("MSE at t = {:.2f}".format(t_eval))
        plt.title(f"PINN MSE for activation = {act}")
        plt.tight_layout()
        plt.show()


if __name__ == "__main__":
    run_architecture_sweep()
# Out:
# === Training tanh-L1-W10 ===
# tanh-L1-W10: MSE = 4.331e-02
#
# === Training tanh-L1-W20 ===
# tanh-L1-W20: MSE = 3.117e-02
#
# === Training tanh-L1-W50 ===
# tanh-L1-W50: MSE = 4.871e-03
#
# === Training tanh-L2-W10 ===
# tanh-L2-W10: MSE = 3.987e-02
#
# === Training tanh-L2-W20 ===
# tanh-L2-W20: MSE = 3.766e-02
#
# === Training tanh-L2-W50 ===
# tanh-L2-W50: MSE = 1.827e-05
#
# === Training tanh-L3-W10 ===
# tanh-L3-W10: MSE = 3.815e-02
#
# === Training tanh-L3-W20 ===
# tanh-L3-W20: MSE = 1.899e-03
#
# === Training tanh-L3-W50 ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 297
#     293         plt.show()
#     296 if __name__ == "__main__":
# --> 297     run_architecture_sweep()
#
# Cell In[4], line 253, in run_architecture_sweep()
#     250 print(f"\n=== Training {label} ===")
#     252 model = PINN(layers=layers, activation=act)
# --> 253 model.train_pinn(x_coll, t_coll,
#     254                  epochs=2000, lr=1e-3,
#     255                  optimizer_cls=optim.Adam,
#     256                  verbose_every=0)
#     258 with torch.no_grad():
#     259     t_test = torch.full_like(x_test, t_eval)
#
# Cell In[4], line 187, in PINN.train_pinn(self, x_coll, t_coll, epochs, lr, optimizer_cls, verbose_every)
#     185 loss = self.loss(x_coll, t_coll)
#     186 loss.backward()
# --> 187 optimizer.step()
#     189 if verbose_every and epoch % verbose_every == 0:
#     190     print(f"Epoch {epoch:5d} | Loss = {loss.item():.3e}")
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/optim/optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/optim/optimizer.py:82, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      80     torch.set_grad_enabled(self.defaults["differentiable"])
#      81     torch._dynamo.graph_break()
# ---> 82     ret = func(*args, **kwargs)
#      83 finally:
#      84     torch._dynamo.graph_break()
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/optim/adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)
#     244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/optim/optimizer.py:150, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     148     return disabled_func(*args, **kwargs)
#     149 else:
# --> 150     return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/optim/adam.py:953, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     950 else:
#     951     func = _single_tensor_adam
# --> 953 func(
#     954     params,
#     955     grads,
#     956     exp_avgs,
#     957     exp_avg_sqs,
#     958     max_exp_avg_sqs,
#     959     state_steps,
#     960     amsgrad=amsgrad,
#     961     has_complex=has_complex,
#     962     beta1=beta1,
#     963     beta2=beta2,
#     964     lr=lr,
#     965     weight_decay=weight_decay,
#     966     eps=eps,
#     967     maximize=maximize,
#     968     capturable=capturable,
#     969     differentiable=differentiable,
#     970     grad_scale=grad_scale,
#     971     found_inf=found_inf,
#     972     decoupled_weight_decay=decoupled_weight_decay,
#     973 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/torch/optim/adam.py:535, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     533         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     534     else:
# --> 535         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     537     param.addcdiv_(exp_avg, denom, value=-step_size)  # type: ignore[arg-type]
#     539 # Lastly, switch back to complex view
#
# KeyboardInterrupt:

# %%
import torch
import time

# analytical solution
def analytical_diffusion(x, t):
    return torch.exp(-torch.pi**2 * t) * torch.sin(torch.pi * x)

def get_activation(name):
    """
    Return a PyTorch activation module given a name or module.

    Parameters
    ----------
    name : str or nn.Module
        Name of the activation ("tanh", "relu", "sigmoid", "gelu") or a
        pre-instantiated torch.nn.Module.

    Returns
    -------
    nn.Module
        Activation function module.
    """
    if isinstance(name, nn.Module):
        return name
    name = name.lower()
    if name == "leaky":
        return nn.LeakyReLU()
    if name == "elu":
        return nn.ELU()
    if name == "tanh":
        return nn.Tanh()
    if name == "relu":
        return nn.ReLU()
    if name == "sigmoid":
        return nn.Sigmoid()
    if name == "gelu":
        return nn.GELU()
    raise ValueError(f"Unknown activation: {name}")

# test / collocation points
N_test = 100
x_test = torch.rand(N_test, 1)
t_test = torch.rand(N_test, 1)
u_exact = analytical_diffusion(x_test, t_test)

learning_rates = [1e-1, 1e-2, 1e-3, 1e-4]
epoch_list     = [1000, 2000, 5000]
activations    = ["elu", "tanh", "relu", "gelu", "sigmoid", "leaky"]
node_sizes     = [10, 20, 50,100,200]
hidden_layers  = [1, 2, 3,4,5]


for lr in learning_rates:
    print(f"\n=== Learning rate: {lr} ===")

    for epochs in epoch_list:
        print(f"  Epochs: {epochs}")

        for act in activations:
            for nodes in node_sizes:
                for layers in hidden_layers:

                    layer_config = [2] + [nodes] * layers + [1]

                    model = PINN(
                        layers=layer_config,
                        activation=act,
                        
                    )

                    start_time = time.time()

                    model.train_pinn(
                        x_coll=x_test,
                        t_coll=t_test,
                        epochs=epochs,
                        lr=lr,
                        verbose_every=None
                    )

                    with torch.no_grad():
                        u_pred = model.trial_solution(x_test, t_test)
                        mse = torch.mean((u_pred - u_exact)**2).item()

                    elapsed = time.time() - start_time

                    print(
                        f"MSE: {mse:.3e} | "
                        f"LR={lr}, epochs={epochs}, "
                        f"layers={layers}, nodes={nodes}, act={act} | "
                        f"time={elapsed:.2f}s"
                    )

                    model.train_pinn(
                        x_coll=x_test,
                        t_coll=t_test,
                        epochs=epochs,
                        lr=lr,
                        verbose_every=None
                    )

                    with torch.no_grad():
                        u_pred = model.trial_solution(x_test, t_test)
                        mse = torch.mean((u_pred - u_exact)**2).item()

                    elapsed = time.time() - start_time

                    print(
                        f"MSE: {mse:.3e} | "
                        f"LR={lr}, epochs={epochs}, "
                        f"layers={layers}, nodes={nodes}, act={act} | "
                        f"time={elapsed:.2f}s"
                    )
# Out:
# === Learning rate: 0.1 ===
#   Epochs: 1000
# MSE: 1.001e-04 | LR=0.1, epochs=1000, layers=1, nodes=10, act=elu | time=0.55s
# MSE: 9.565e-05 | LR=0.1, epochs=1000, layers=1, nodes=10, act=elu | time=1.13s
# MSE: 4.420e-05 | LR=0.1, epochs=1000, layers=2, nodes=10, act=elu | time=0.75s
# MSE: 1.099e-05 | LR=0.1, epochs=1000, layers=2, nodes=10, act=elu | time=1.39s
# MSE: 1.025e-05 | LR=0.1, epochs=1000, layers=3, nodes=10, act=elu | time=0.81s
# MSE: 3.662e-05 | LR=0.1, epochs=1000, layers=3, nodes=10, act=elu | time=1.65s
# MSE: 4.468e-05 | LR=0.1, epochs=1000, layers=4, nodes=10, act=elu | time=0.98s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=10, act=elu | time=2.00s
# MSE: 2.094e-04 | LR=0.1, epochs=1000, layers=5, nodes=10, act=elu | time=1.20s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=10, act=elu | time=2.41s
# MSE: 1.481e-04 | LR=0.1, epochs=1000, layers=1, nodes=20, act=elu | time=0.61s
# MSE: 4.619e-05 | LR=0.1, epochs=1000, layers=1, nodes=20, act=elu | time=1.21s
# MSE: 1.430e-04 | LR=0.1, epochs=1000, layers=2, nodes=20, act=elu | time=0.88s
# MSE: 1.397e-05 | LR=0.1, epochs=1000, layers=2, nodes=20, act=elu | time=1.74s
# MSE: 1.869e-05 | LR=0.1, epochs=1000, layers=3, nodes=20, act=elu | time=1.02s
# MSE: 7.072e-05 | LR=0.1, epochs=1000, layers=3, nodes=20, act=elu | time=2.06s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=20, act=elu | time=1.25s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=20, act=elu | time=2.51s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=20, act=elu | time=1.45s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=20, act=elu | time=2.96s
# MSE: 3.277e-05 | LR=0.1, epochs=1000, layers=1, nodes=50, act=elu | time=0.70s
# MSE: 5.894e-05 | LR=0.1, epochs=1000, layers=1, nodes=50, act=elu | time=1.40s
# MSE: 2.641e-05 | LR=0.1, epochs=1000, layers=2, nodes=50, act=elu | time=1.18s
# MSE: 4.007e-04 | LR=0.1, epochs=1000, layers=2, nodes=50, act=elu | time=2.38s
# MSE: 2.032e-05 | LR=0.1, epochs=1000, layers=3, nodes=50, act=elu | time=1.52s
# MSE: 2.217e-03 | LR=0.1, epochs=1000, layers=3, nodes=50, act=elu | time=3.01s
# MSE: 7.079e-04 | LR=0.1, epochs=1000, layers=4, nodes=50, act=elu | time=1.86s
# MSE: 3.508e-04 | LR=0.1, epochs=1000, layers=4, nodes=50, act=elu | time=3.72s
# MSE: 1.057e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=elu | time=2.30s
# MSE: 2.687e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=elu | time=4.53s
# MSE: 3.669e-05 | LR=0.1, epochs=1000, layers=1, nodes=100, act=elu | time=0.80s
# MSE: 1.240e-04 | LR=0.1, epochs=1000, layers=1, nodes=100, act=elu | time=1.61s
# MSE: 9.477e-06 | LR=0.1, epochs=1000, layers=2, nodes=100, act=elu | time=1.49s
# MSE: 4.310e-02 | LR=0.1, epochs=1000, layers=2, nodes=100, act=elu | time=2.97s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=elu | time=2.20s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=elu | time=4.39s
# MSE: 9.675e-03 | LR=0.1, epochs=1000, layers=4, nodes=100, act=elu | time=2.77s
# MSE: 8.113e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=elu | time=5.62s
# MSE: 4.624e-02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=elu | time=3.47s
# MSE: 1.104e+01 | LR=0.1, epochs=1000, layers=5, nodes=100, act=elu | time=6.73s
# MSE: 9.903e-05 | LR=0.1, epochs=1000, layers=1, nodes=200, act=elu | time=1.10s
# MSE: 3.047e-05 | LR=0.1, epochs=1000, layers=1, nodes=200, act=elu | time=2.30s
# MSE: 4.478e-03 | LR=0.1, epochs=1000, layers=2, nodes=200, act=elu | time=2.59s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=200, act=elu | time=5.50s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=200, act=elu | time=3.95s
# MSE: 4.313e-02 | LR=0.1, epochs=1000, layers=3, nodes=200, act=elu | time=7.84s
# MSE: 9.853e-03 | LR=0.1, epochs=1000, layers=4, nodes=200, act=elu | time=5.48s
# MSE: 3.250e-01 | LR=0.1, epochs=1000, layers=4, nodes=200, act=elu | time=10.96s
# MSE: 1.113e-01 | LR=0.1, epochs=1000, layers=5, nodes=200, act=elu | time=6.92s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=elu | time=13.60s
# MSE: 3.498e-05 | LR=0.1, epochs=1000, layers=1, nodes=10, act=tanh | time=0.48s
# MSE: 2.659e-05 | LR=0.1, epochs=1000, layers=1, nodes=10, act=tanh | time=0.96s
# MSE: 7.524e-05 | LR=0.1, epochs=1000, layers=2, nodes=10, act=tanh | time=0.63s
# MSE: 1.333e-03 | LR=0.1, epochs=1000, layers=2, nodes=10, act=tanh | time=1.27s
# MSE: 2.730e-04 | LR=0.1, epochs=1000, layers=3, nodes=10, act=tanh | time=0.79s
# MSE: 7.696e-06 | LR=0.1, epochs=1000, layers=3, nodes=10, act=tanh | time=1.58s
# MSE: 2.841e-03 | LR=0.1, epochs=1000, layers=4, nodes=10, act=tanh | time=0.93s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=10, act=tanh | time=1.86s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=10, act=tanh | time=1.07s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=10, act=tanh | time=2.15s
# MSE: 1.456e-05 | LR=0.1, epochs=1000, layers=1, nodes=20, act=tanh | time=0.53s
# MSE: 3.028e-06 | LR=0.1, epochs=1000, layers=1, nodes=20, act=tanh | time=1.06s
# MSE: 5.187e-05 | LR=0.1, epochs=1000, layers=2, nodes=20, act=tanh | time=0.73s
# MSE: 2.513e-04 | LR=0.1, epochs=1000, layers=2, nodes=20, act=tanh | time=1.46s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=20, act=tanh | time=0.89s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=20, act=tanh | time=1.76s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=20, act=tanh | time=1.01s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=20, act=tanh | time=2.02s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=20, act=tanh | time=1.23s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=20, act=tanh | time=2.47s
# MSE: 2.761e-05 | LR=0.1, epochs=1000, layers=1, nodes=50, act=tanh | time=0.69s
# MSE: 4.259e-06 | LR=0.1, epochs=1000, layers=1, nodes=50, act=tanh | time=1.39s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=50, act=tanh | time=1.02s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=50, act=tanh | time=2.12s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=50, act=tanh | time=1.31s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=50, act=tanh | time=2.64s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=50, act=tanh | time=1.60s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=50, act=tanh | time=3.19s
# MSE: 4.299e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=tanh | time=1.88s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=tanh | time=3.73s
# MSE: 1.762e-05 | LR=0.1, epochs=1000, layers=1, nodes=100, act=tanh | time=0.81s
# MSE: 1.818e-06 | LR=0.1, epochs=1000, layers=1, nodes=100, act=tanh | time=1.63s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=100, act=tanh | time=1.26s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=100, act=tanh | time=2.51s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=tanh | time=1.60s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=tanh | time=3.22s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=tanh | time=1.98s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=tanh | time=3.94s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=tanh | time=2.38s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=tanh | time=4.74s
# MSE: 3.328e-05 | LR=0.1, epochs=1000, layers=1, nodes=200, act=tanh | time=0.96s
# MSE: 1.054e-05 | LR=0.1, epochs=1000, layers=1, nodes=200, act=tanh | time=1.83s
# MSE: 4.323e-02 | LR=0.1, epochs=1000, layers=2, nodes=200, act=tanh | time=1.90s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=200, act=tanh | time=3.79s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=200, act=tanh | time=2.99s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=200, act=tanh | time=6.07s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=200, act=tanh | time=4.17s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=200, act=tanh | time=8.44s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=tanh | time=5.16s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=tanh | time=10.18s
# MSE: 1.264e-02 | LR=0.1, epochs=1000, layers=1, nodes=10, act=relu | time=0.47s
# MSE: 1.319e-02 | LR=0.1, epochs=1000, layers=1, nodes=10, act=relu | time=0.95s
# MSE: 8.847e-03 | LR=0.1, epochs=1000, layers=2, nodes=10, act=relu | time=0.59s
# MSE: 1.260e-02 | LR=0.1, epochs=1000, layers=2, nodes=10, act=relu | time=1.16s
# MSE: 8.847e-03 | LR=0.1, epochs=1000, layers=3, nodes=10, act=relu | time=0.68s
# MSE: 8.502e-03 | LR=0.1, epochs=1000, layers=3, nodes=10, act=relu | time=1.35s
# MSE: 1.268e-02 | LR=0.1, epochs=1000, layers=4, nodes=10, act=relu | time=0.78s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=10, act=relu | time=1.56s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=10, act=relu | time=0.89s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=10, act=relu | time=1.77s
# MSE: 8.847e-03 | LR=0.1, epochs=1000, layers=1, nodes=20, act=relu | time=0.49s
# MSE: 9.278e-03 | LR=0.1, epochs=1000, layers=1, nodes=20, act=relu | time=1.00s
# MSE: 8.502e-03 | LR=0.1, epochs=1000, layers=2, nodes=20, act=relu | time=0.68s
# MSE: 8.102e-03 | LR=0.1, epochs=1000, layers=2, nodes=20, act=relu | time=1.37s
# MSE: 8.740e-03 | LR=0.1, epochs=1000, layers=3, nodes=20, act=relu | time=0.78s
# MSE: 6.540e-03 | LR=0.1, epochs=1000, layers=3, nodes=20, act=relu | time=1.56s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=20, act=relu | time=0.88s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=20, act=relu | time=1.76s
# MSE: 9.154e-03 | LR=0.1, epochs=1000, layers=5, nodes=20, act=relu | time=1.00s
# MSE: 8.847e-03 | LR=0.1, epochs=1000, layers=5, nodes=20, act=relu | time=1.97s
# MSE: 6.282e-03 | LR=0.1, epochs=1000, layers=1, nodes=50, act=relu | time=0.53s
# MSE: 1.246e-02 | LR=0.1, epochs=1000, layers=1, nodes=50, act=relu | time=1.06s
# MSE: 1.260e-02 | LR=0.1, epochs=1000, layers=2, nodes=50, act=relu | time=0.83s
# MSE: 1.329e-02 | LR=0.1, epochs=1000, layers=2, nodes=50, act=relu | time=1.64s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=50, act=relu | time=0.98s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=50, act=relu | time=1.95s
# MSE: 8.717e-03 | LR=0.1, epochs=1000, layers=4, nodes=50, act=relu | time=1.14s
# MSE: 1.268e-02 | LR=0.1, epochs=1000, layers=4, nodes=50, act=relu | time=2.31s
# MSE: 7.751e-03 | LR=0.1, epochs=1000, layers=5, nodes=50, act=relu | time=1.34s
# MSE: 1.187e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=relu | time=2.67s
# MSE: 6.896e-03 | LR=0.1, epochs=1000, layers=1, nodes=100, act=relu | time=0.60s
# MSE: 1.220e-02 | LR=0.1, epochs=1000, layers=1, nodes=100, act=relu | time=1.18s
# MSE: 4.263e-03 | LR=0.1, epochs=1000, layers=2, nodes=100, act=relu | time=1.00s
# MSE: 4.641e-03 | LR=0.1, epochs=1000, layers=2, nodes=100, act=relu | time=1.99s
# MSE: 8.371e-03 | LR=0.1, epochs=1000, layers=3, nodes=100, act=relu | time=1.14s
# MSE: 1.189e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=relu | time=2.26s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=relu | time=1.36s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=relu | time=2.74s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=relu | time=1.62s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=relu | time=3.24s
# MSE: 6.642e-03 | LR=0.1, epochs=1000, layers=1, nodes=200, act=relu | time=0.64s
# MSE: 1.259e-02 | LR=0.1, epochs=1000, layers=1, nodes=200, act=relu | time=1.29s
# MSE: 2.417e-03 | LR=0.1, epochs=1000, layers=2, nodes=200, act=relu | time=1.49s
# MSE: 7.853e-03 | LR=0.1, epochs=1000, layers=2, nodes=200, act=relu | time=2.96s
# MSE: 3.684e-03 | LR=0.1, epochs=1000, layers=3, nodes=200, act=relu | time=2.21s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=200, act=relu | time=4.47s
# MSE: 4.563e-02 | LR=0.1, epochs=1000, layers=4, nodes=200, act=relu | time=2.93s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=200, act=relu | time=5.86s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=relu | time=3.61s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=relu | time=7.47s
# MSE: 3.999e-05 | LR=0.1, epochs=1000, layers=1, nodes=10, act=gelu | time=0.56s
# MSE: 2.708e-05 | LR=0.1, epochs=1000, layers=1, nodes=10, act=gelu | time=1.13s
# MSE: 4.848e-05 | LR=0.1, epochs=1000, layers=2, nodes=10, act=gelu | time=0.82s
# MSE: 1.506e-06 | LR=0.1, epochs=1000, layers=2, nodes=10, act=gelu | time=1.62s
# MSE: 1.563e-04 | LR=0.1, epochs=1000, layers=3, nodes=10, act=gelu | time=1.10s
# MSE: 4.765e-07 | LR=0.1, epochs=1000, layers=3, nodes=10, act=gelu | time=2.17s
# MSE: 1.772e-06 | LR=0.1, epochs=1000, layers=4, nodes=10, act=gelu | time=1.34s
# MSE: 4.074e-05 | LR=0.1, epochs=1000, layers=4, nodes=10, act=gelu | time=2.65s
# MSE: 2.157e-05 | LR=0.1, epochs=1000, layers=5, nodes=10, act=gelu | time=1.52s
# MSE: 7.376e-03 | LR=0.1, epochs=1000, layers=5, nodes=10, act=gelu | time=3.00s
# MSE: 3.877e-06 | LR=0.1, epochs=1000, layers=1, nodes=20, act=gelu | time=0.68s
# MSE: 3.325e-06 | LR=0.1, epochs=1000, layers=1, nodes=20, act=gelu | time=1.32s
# MSE: 5.655e-06 | LR=0.1, epochs=1000, layers=2, nodes=20, act=gelu | time=0.92s
# MSE: 3.333e-04 | LR=0.1, epochs=1000, layers=2, nodes=20, act=gelu | time=1.91s
# MSE: 1.965e-05 | LR=0.1, epochs=1000, layers=3, nodes=20, act=gelu | time=1.19s
# MSE: 4.489e-06 | LR=0.1, epochs=1000, layers=3, nodes=20, act=gelu | time=2.37s
# MSE: 1.306e-04 | LR=0.1, epochs=1000, layers=4, nodes=20, act=gelu | time=1.46s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=20, act=gelu | time=2.98s
# MSE: 1.474e-04 | LR=0.1, epochs=1000, layers=5, nodes=20, act=gelu | time=1.71s
# MSE: 2.448e-06 | LR=0.1, epochs=1000, layers=5, nodes=20, act=gelu | time=3.35s
# MSE: 3.228e-06 | LR=0.1, epochs=1000, layers=1, nodes=50, act=gelu | time=0.97s
# MSE: 1.410e-06 | LR=0.1, epochs=1000, layers=1, nodes=50, act=gelu | time=1.95s
# MSE: 1.324e-06 | LR=0.1, epochs=1000, layers=2, nodes=50, act=gelu | time=1.65s
# MSE: 3.028e-06 | LR=0.1, epochs=1000, layers=2, nodes=50, act=gelu | time=3.26s
# MSE: 3.872e-07 | LR=0.1, epochs=1000, layers=3, nodes=50, act=gelu | time=2.22s
# MSE: 3.800e-05 | LR=0.1, epochs=1000, layers=3, nodes=50, act=gelu | time=4.47s
# MSE: 7.200e-07 | LR=0.1, epochs=1000, layers=4, nodes=50, act=gelu | time=2.83s
# MSE: 2.105e-04 | LR=0.1, epochs=1000, layers=4, nodes=50, act=gelu | time=5.70s
# MSE: 1.698e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=gelu | time=3.55s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=gelu | time=7.05s
# MSE: 5.156e-06 | LR=0.1, epochs=1000, layers=1, nodes=100, act=gelu | time=1.31s
# MSE: 1.514e-06 | LR=0.1, epochs=1000, layers=1, nodes=100, act=gelu | time=2.59s
# MSE: 4.550e-05 | LR=0.1, epochs=1000, layers=2, nodes=100, act=gelu | time=2.36s
# MSE: 3.011e-05 | LR=0.1, epochs=1000, layers=2, nodes=100, act=gelu | time=4.79s
# MSE: 6.356e-04 | LR=0.1, epochs=1000, layers=3, nodes=100, act=gelu | time=3.45s
# MSE: 1.991e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=gelu | time=6.78s
# MSE: 9.616e-04 | LR=0.1, epochs=1000, layers=4, nodes=100, act=gelu | time=4.28s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=gelu | time=8.58s
# MSE: 3.432e+00 | LR=0.1, epochs=1000, layers=5, nodes=100, act=gelu | time=5.09s
# MSE: 4.451e-02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=gelu | time=10.45s
# MSE: 7.353e-06 | LR=0.1, epochs=1000, layers=1, nodes=200, act=gelu | time=1.62s
# MSE: 1.838e-06 | LR=0.1, epochs=1000, layers=1, nodes=200, act=gelu | time=3.25s
# MSE: 1.110e-04 | LR=0.1, epochs=1000, layers=2, nodes=200, act=gelu | time=3.61s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=200, act=gelu | time=7.19s
# MSE: 6.923e-04 | LR=0.1, epochs=1000, layers=3, nodes=200, act=gelu | time=5.71s
# MSE: 9.106e+03 | LR=0.1, epochs=1000, layers=3, nodes=200, act=gelu | time=11.60s
# MSE: 3.614e-02 | LR=0.1, epochs=1000, layers=4, nodes=200, act=gelu | time=7.38s
# MSE: 2.384e-03 | LR=0.1, epochs=1000, layers=4, nodes=200, act=gelu | time=14.76s
# MSE: 6.086e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=gelu | time=8.76s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=gelu | time=17.50s
# MSE: 1.078e-04 | LR=0.1, epochs=1000, layers=1, nodes=10, act=sigmoid | time=0.53s
# MSE: 4.031e-05 | LR=0.1, epochs=1000, layers=1, nodes=10, act=sigmoid | time=1.06s
# MSE: 4.018e-05 | LR=0.1, epochs=1000, layers=2, nodes=10, act=sigmoid | time=0.69s
# MSE: 9.835e-06 | LR=0.1, epochs=1000, layers=2, nodes=10, act=sigmoid | time=1.37s
# MSE: 2.012e-05 | LR=0.1, epochs=1000, layers=3, nodes=10, act=sigmoid | time=0.85s
# MSE: 6.768e-06 | LR=0.1, epochs=1000, layers=3, nodes=10, act=sigmoid | time=1.69s
# MSE: 2.010e-04 | LR=0.1, epochs=1000, layers=4, nodes=10, act=sigmoid | time=1.02s
# MSE: 9.112e-06 | LR=0.1, epochs=1000, layers=4, nodes=10, act=sigmoid | time=2.03s
# MSE: 3.659e-06 | LR=0.1, epochs=1000, layers=5, nodes=10, act=sigmoid | time=1.12s
# MSE: 6.093e-06 | LR=0.1, epochs=1000, layers=5, nodes=10, act=sigmoid | time=2.31s
# MSE: 1.356e-05 | LR=0.1, epochs=1000, layers=1, nodes=20, act=sigmoid | time=0.55s
# MSE: 3.300e-06 | LR=0.1, epochs=1000, layers=1, nodes=20, act=sigmoid | time=1.17s
# MSE: 4.115e-06 | LR=0.1, epochs=1000, layers=2, nodes=20, act=sigmoid | time=0.74s
# MSE: 5.888e-07 | LR=0.1, epochs=1000, layers=2, nodes=20, act=sigmoid | time=1.49s
# MSE: 9.591e-06 | LR=0.1, epochs=1000, layers=3, nodes=20, act=sigmoid | time=0.90s
# MSE: 4.607e-06 | LR=0.1, epochs=1000, layers=3, nodes=20, act=sigmoid | time=1.79s
# MSE: 2.745e-06 | LR=0.1, epochs=1000, layers=4, nodes=20, act=sigmoid | time=1.06s
# MSE: 7.146e-05 | LR=0.1, epochs=1000, layers=4, nodes=20, act=sigmoid | time=2.12s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=20, act=sigmoid | time=1.22s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=20, act=sigmoid | time=2.43s
# MSE: 5.814e-06 | LR=0.1, epochs=1000, layers=1, nodes=50, act=sigmoid | time=0.57s
# MSE: 3.338e-06 | LR=0.1, epochs=1000, layers=1, nodes=50, act=sigmoid | time=1.14s
# MSE: 1.497e-03 | LR=0.1, epochs=1000, layers=2, nodes=50, act=sigmoid | time=0.93s
# MSE: 1.112e-03 | LR=0.1, epochs=1000, layers=2, nodes=50, act=sigmoid | time=1.92s
# MSE: 6.685e-06 | LR=0.1, epochs=1000, layers=3, nodes=50, act=sigmoid | time=1.18s
# MSE: 8.302e-06 | LR=0.1, epochs=1000, layers=3, nodes=50, act=sigmoid | time=2.36s
# MSE: 4.459e-02 | LR=0.1, epochs=1000, layers=4, nodes=50, act=sigmoid | time=1.46s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=50, act=sigmoid | time=2.91s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=sigmoid | time=1.74s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=sigmoid | time=3.45s
# MSE: 1.882e-05 | LR=0.1, epochs=1000, layers=1, nodes=100, act=sigmoid | time=0.64s
# MSE: 1.378e-06 | LR=0.1, epochs=1000, layers=1, nodes=100, act=sigmoid | time=1.28s
# MSE: 6.604e-05 | LR=0.1, epochs=1000, layers=2, nodes=100, act=sigmoid | time=1.10s
# MSE: 5.733e-05 | LR=0.1, epochs=1000, layers=2, nodes=100, act=sigmoid | time=2.20s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=sigmoid | time=1.55s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=sigmoid | time=3.15s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=sigmoid | time=1.89s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=sigmoid | time=3.76s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=sigmoid | time=2.18s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=sigmoid | time=4.39s
# MSE: 7.321e-05 | LR=0.1, epochs=1000, layers=1, nodes=200, act=sigmoid | time=0.73s
# MSE: 3.152e-06 | LR=0.1, epochs=1000, layers=1, nodes=200, act=sigmoid | time=1.46s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=200, act=sigmoid | time=1.94s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=2, nodes=200, act=sigmoid | time=3.89s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=200, act=sigmoid | time=2.83s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=3, nodes=200, act=sigmoid | time=5.71s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=200, act=sigmoid | time=3.98s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=4, nodes=200, act=sigmoid | time=8.21s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=sigmoid | time=4.99s
# MSE: 4.314e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=sigmoid | time=9.98s
# MSE: 8.847e-03 | LR=0.1, epochs=1000, layers=1, nodes=10, act=leaky | time=0.47s
# MSE: 8.847e-03 | LR=0.1, epochs=1000, layers=1, nodes=10, act=leaky | time=0.96s
# MSE: 1.189e-02 | LR=0.1, epochs=1000, layers=2, nodes=10, act=leaky | time=0.60s
# MSE: 8.847e-03 | LR=0.1, epochs=1000, layers=2, nodes=10, act=leaky | time=1.20s
# MSE: 8.652e-03 | LR=0.1, epochs=1000, layers=3, nodes=10, act=leaky | time=0.70s
# MSE: 7.460e-03 | LR=0.1, epochs=1000, layers=3, nodes=10, act=leaky | time=1.40s
# MSE: 7.636e-03 | LR=0.1, epochs=1000, layers=4, nodes=10, act=leaky | time=0.86s
# MSE: 8.692e-03 | LR=0.1, epochs=1000, layers=4, nodes=10, act=leaky | time=1.73s
# MSE: 3.608e-02 | LR=0.1, epochs=1000, layers=5, nodes=10, act=leaky | time=0.97s
# MSE: 1.558e-02 | LR=0.1, epochs=1000, layers=5, nodes=10, act=leaky | time=1.91s
# MSE: 8.529e-03 | LR=0.1, epochs=1000, layers=1, nodes=20, act=leaky | time=0.51s
# MSE: 1.259e-02 | LR=0.1, epochs=1000, layers=1, nodes=20, act=leaky | time=1.01s
# MSE: 5.402e-03 | LR=0.1, epochs=1000, layers=2, nodes=20, act=leaky | time=0.63s
# MSE: 1.184e-02 | LR=0.1, epochs=1000, layers=2, nodes=20, act=leaky | time=1.26s
# MSE: 8.497e-03 | LR=0.1, epochs=1000, layers=3, nodes=20, act=leaky | time=0.75s
# MSE: 3.715e-02 | LR=0.1, epochs=1000, layers=3, nodes=20, act=leaky | time=1.49s
# MSE: 5.055e-03 | LR=0.1, epochs=1000, layers=4, nodes=20, act=leaky | time=0.84s
# MSE: 7.619e-03 | LR=0.1, epochs=1000, layers=4, nodes=20, act=leaky | time=1.67s
# MSE: 1.275e-02 | LR=0.1, epochs=1000, layers=5, nodes=20, act=leaky | time=0.95s
# MSE: 2.007e-02 | LR=0.1, epochs=1000, layers=5, nodes=20, act=leaky | time=1.88s
# MSE: 6.959e-03 | LR=0.1, epochs=1000, layers=1, nodes=50, act=leaky | time=0.52s
# MSE: 4.315e-03 | LR=0.1, epochs=1000, layers=1, nodes=50, act=leaky | time=1.06s
# MSE: 9.397e-03 | LR=0.1, epochs=1000, layers=2, nodes=50, act=leaky | time=0.87s
# MSE: 5.242e-03 | LR=0.1, epochs=1000, layers=2, nodes=50, act=leaky | time=1.74s
# MSE: 8.750e-03 | LR=0.1, epochs=1000, layers=3, nodes=50, act=leaky | time=0.99s
# MSE: 6.792e-03 | LR=0.1, epochs=1000, layers=3, nodes=50, act=leaky | time=1.97s
# MSE: 1.689e-02 | LR=0.1, epochs=1000, layers=4, nodes=50, act=leaky | time=1.17s
# MSE: 2.131e-02 | LR=0.1, epochs=1000, layers=4, nodes=50, act=leaky | time=2.33s
# MSE: 5.592e-01 | LR=0.1, epochs=1000, layers=5, nodes=50, act=leaky | time=1.32s
# MSE: 5.811e-02 | LR=0.1, epochs=1000, layers=5, nodes=50, act=leaky | time=2.63s
# MSE: 4.823e-03 | LR=0.1, epochs=1000, layers=1, nodes=100, act=leaky | time=0.57s
# MSE: 4.345e-03 | LR=0.1, epochs=1000, layers=1, nodes=100, act=leaky | time=1.16s
# MSE: 8.392e-03 | LR=0.1, epochs=1000, layers=2, nodes=100, act=leaky | time=1.00s
# MSE: 4.440e-03 | LR=0.1, epochs=1000, layers=2, nodes=100, act=leaky | time=1.98s
# MSE: 1.078e-02 | LR=0.1, epochs=1000, layers=3, nodes=100, act=leaky | time=1.17s
# MSE: 4.060e-03 | LR=0.1, epochs=1000, layers=3, nodes=100, act=leaky | time=2.31s
# MSE: 2.611e-01 | LR=0.1, epochs=1000, layers=4, nodes=100, act=leaky | time=1.48s
# MSE: 1.436e-02 | LR=0.1, epochs=1000, layers=4, nodes=100, act=leaky | time=2.90s
# MSE: 1.687e+02 | LR=0.1, epochs=1000, layers=5, nodes=100, act=leaky | time=1.62s
# MSE: 6.218e+00 | LR=0.1, epochs=1000, layers=5, nodes=100, act=leaky | time=3.26s
# MSE: 6.316e-03 | LR=0.1, epochs=1000, layers=1, nodes=200, act=leaky | time=0.62s
# MSE: 4.086e-03 | LR=0.1, epochs=1000, layers=1, nodes=200, act=leaky | time=1.25s
# MSE: 1.020e-02 | LR=0.1, epochs=1000, layers=2, nodes=200, act=leaky | time=1.49s
# MSE: 4.852e-03 | LR=0.1, epochs=1000, layers=2, nodes=200, act=leaky | time=3.05s
# MSE: 1.743e-03 | LR=0.1, epochs=1000, layers=3, nodes=200, act=leaky | time=2.18s
# MSE: 2.366e-03 | LR=0.1, epochs=1000, layers=3, nodes=200, act=leaky | time=4.38s
# MSE: 1.219e-02 | LR=0.1, epochs=1000, layers=4, nodes=200, act=leaky | time=2.86s
# MSE: 8.737e-03 | LR=0.1, epochs=1000, layers=4, nodes=200, act=leaky | time=5.77s
# MSE: 1.461e-02 | LR=0.1, epochs=1000, layers=5, nodes=200, act=leaky | time=3.60s
# MSE: 4.222e-03 | LR=0.1, epochs=1000, layers=5, nodes=200, act=leaky | time=7.19s
#   Epochs: 2000
# MSE: 5.731e-04 | LR=0.1, epochs=2000, layers=1, nodes=10, act=elu | time=1.11s
# MSE: 1.547e-04 | LR=0.1, epochs=2000, layers=1, nodes=10, act=elu | time=2.23s
# MSE: 1.397e-05 | LR=0.1, epochs=2000, layers=2, nodes=10, act=elu | time=1.48s
# MSE: 5.085e-05 | LR=0.1, epochs=2000, layers=2, nodes=10, act=elu | time=2.99s
# MSE: 2.767e-05 | LR=0.1, epochs=2000, layers=3, nodes=10, act=elu | time=1.79s
# MSE: 1.959e-04 | LR=0.1, epochs=2000, layers=3, nodes=10, act=elu | time=3.57s
# MSE: 4.441e-05 | LR=0.1, epochs=2000, layers=4, nodes=10, act=elu | time=2.14s
# MSE: 4.257e-05 | LR=0.1, epochs=2000, layers=4, nodes=10, act=elu | time=4.33s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=10, act=elu | time=2.59s
# MSE: 4.291e-02 | LR=0.1, epochs=2000, layers=5, nodes=10, act=elu | time=5.15s
# MSE: 8.460e-05 | LR=0.1, epochs=2000, layers=1, nodes=20, act=elu | time=1.13s
# MSE: 4.688e-05 | LR=0.1, epochs=2000, layers=1, nodes=20, act=elu | time=2.27s
# MSE: 4.286e-05 | LR=0.1, epochs=2000, layers=2, nodes=20, act=elu | time=1.57s
# MSE: 7.040e-05 | LR=0.1, epochs=2000, layers=2, nodes=20, act=elu | time=3.25s
# MSE: 7.308e-06 | LR=0.1, epochs=2000, layers=3, nodes=20, act=elu | time=2.10s
# MSE: 2.071e-05 | LR=0.1, epochs=2000, layers=3, nodes=20, act=elu | time=4.15s
# MSE: 8.415e-05 | LR=0.1, epochs=2000, layers=4, nodes=20, act=elu | time=2.41s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=20, act=elu | time=4.80s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=elu | time=2.76s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=elu | time=5.64s
# MSE: 1.370e-04 | LR=0.1, epochs=2000, layers=1, nodes=50, act=elu | time=1.34s
# MSE: 4.290e-05 | LR=0.1, epochs=2000, layers=1, nodes=50, act=elu | time=2.71s
# MSE: 2.046e-05 | LR=0.1, epochs=2000, layers=2, nodes=50, act=elu | time=2.25s
# MSE: 5.440e-06 | LR=0.1, epochs=2000, layers=2, nodes=50, act=elu | time=4.51s
# MSE: 2.373e-04 | LR=0.1, epochs=2000, layers=3, nodes=50, act=elu | time=2.94s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=elu | time=5.91s
# MSE: 1.100e-04 | LR=0.1, epochs=2000, layers=4, nodes=50, act=elu | time=3.70s
# MSE: 1.145e-03 | LR=0.1, epochs=2000, layers=4, nodes=50, act=elu | time=7.36s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=elu | time=4.37s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=elu | time=8.72s
# MSE: 5.553e-05 | LR=0.1, epochs=2000, layers=1, nodes=100, act=elu | time=1.56s
# MSE: 9.543e-06 | LR=0.1, epochs=2000, layers=1, nodes=100, act=elu | time=3.11s
# MSE: 1.755e-05 | LR=0.1, epochs=2000, layers=2, nodes=100, act=elu | time=2.91s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=2, nodes=100, act=elu | time=5.86s
# MSE: 8.916e-03 | LR=0.1, epochs=2000, layers=3, nodes=100, act=elu | time=4.14s
# MSE: 2.054e-03 | LR=0.1, epochs=2000, layers=3, nodes=100, act=elu | time=8.23s
# MSE: 5.661e-04 | LR=0.1, epochs=2000, layers=4, nodes=100, act=elu | time=5.21s
# MSE: 5.296e-03 | LR=0.1, epochs=2000, layers=4, nodes=100, act=elu | time=10.39s
# MSE: 3.941e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=elu | time=6.34s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=elu | time=12.69s
# MSE: 1.664e-05 | LR=0.1, epochs=2000, layers=1, nodes=200, act=elu | time=2.05s
# MSE: 4.474e-05 | LR=0.1, epochs=2000, layers=1, nodes=200, act=elu | time=4.14s
# MSE: 8.938e-06 | LR=0.1, epochs=2000, layers=2, nodes=200, act=elu | time=5.29s
# MSE: 1.742e-03 | LR=0.1, epochs=2000, layers=2, nodes=200, act=elu | time=10.62s
# MSE: 5.059e-05 | LR=0.1, epochs=2000, layers=3, nodes=200, act=elu | time=7.93s
# MSE: 2.004e-03 | LR=0.1, epochs=2000, layers=3, nodes=200, act=elu | time=15.75s
# MSE: 1.805e-02 | LR=0.1, epochs=2000, layers=4, nodes=200, act=elu | time=10.40s
# MSE: 4.897e-03 | LR=0.1, epochs=2000, layers=4, nodes=200, act=elu | time=20.75s
# MSE: 3.742e-02 | LR=0.1, epochs=2000, layers=5, nodes=200, act=elu | time=12.73s
# MSE: 7.958e-02 | LR=0.1, epochs=2000, layers=5, nodes=200, act=elu | time=25.71s
# MSE: 6.353e-05 | LR=0.1, epochs=2000, layers=1, nodes=10, act=tanh | time=1.04s
# MSE: 2.066e-05 | LR=0.1, epochs=2000, layers=1, nodes=10, act=tanh | time=2.07s
# MSE: 8.689e-06 | LR=0.1, epochs=2000, layers=2, nodes=10, act=tanh | time=1.34s
# MSE: 8.197e-05 | LR=0.1, epochs=2000, layers=2, nodes=10, act=tanh | time=2.65s
# MSE: 1.150e-04 | LR=0.1, epochs=2000, layers=3, nodes=10, act=tanh | time=1.57s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=10, act=tanh | time=3.15s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=10, act=tanh | time=1.90s
# MSE: 4.338e-02 | LR=0.1, epochs=2000, layers=4, nodes=10, act=tanh | time=3.86s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=10, act=tanh | time=2.25s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=10, act=tanh | time=4.42s
# MSE: 2.853e-05 | LR=0.1, epochs=2000, layers=1, nodes=20, act=tanh | time=1.04s
# MSE: 5.935e-07 | LR=0.1, epochs=2000, layers=1, nodes=20, act=tanh | time=2.09s
# MSE: 9.396e-05 | LR=0.1, epochs=2000, layers=2, nodes=20, act=tanh | time=1.37s
# MSE: 2.473e-04 | LR=0.1, epochs=2000, layers=2, nodes=20, act=tanh | time=2.75s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=20, act=tanh | time=1.76s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=20, act=tanh | time=3.54s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=20, act=tanh | time=2.14s
# MSE: 4.318e-02 | LR=0.1, epochs=2000, layers=4, nodes=20, act=tanh | time=4.37s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=tanh | time=2.67s
# MSE: 4.551e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=tanh | time=5.15s
# MSE: 1.290e-03 | LR=0.1, epochs=2000, layers=1, nodes=50, act=tanh | time=1.38s
# MSE: 1.038e-06 | LR=0.1, epochs=2000, layers=1, nodes=50, act=tanh | time=2.75s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=2, nodes=50, act=tanh | time=2.00s
# MSE: 4.315e-02 | LR=0.1, epochs=2000, layers=2, nodes=50, act=tanh | time=3.99s
# MSE: 3.734e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=tanh | time=2.51s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=tanh | time=5.05s
# MSE: 4.472e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=tanh | time=3.02s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=tanh | time=6.06s
# MSE: 4.769e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=tanh | time=3.60s
# MSE: 4.321e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=tanh | time=7.20s
# MSE: 9.535e-06 | LR=0.1, epochs=2000, layers=1, nodes=100, act=tanh | time=1.59s
# MSE: 2.005e-07 | LR=0.1, epochs=2000, layers=1, nodes=100, act=tanh | time=3.18s
# MSE: 4.341e-02 | LR=0.1, epochs=2000, layers=2, nodes=100, act=tanh | time=2.42s
# MSE: 4.313e-02 | LR=0.1, epochs=2000, layers=2, nodes=100, act=tanh | time=4.83s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=100, act=tanh | time=3.39s
# MSE: 4.315e-02 | LR=0.1, epochs=2000, layers=3, nodes=100, act=tanh | time=6.79s
# MSE: 4.309e-02 | LR=0.1, epochs=2000, layers=4, nodes=100, act=tanh | time=4.03s
# MSE: 3.935e-02 | LR=0.1, epochs=2000, layers=4, nodes=100, act=tanh | time=8.06s
# MSE: 4.048e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=tanh | time=4.79s
# MSE: 3.800e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=tanh | time=9.60s
# MSE: 8.207e-06 | LR=0.1, epochs=2000, layers=1, nodes=200, act=tanh | time=1.74s
# MSE: 7.160e-07 | LR=0.1, epochs=2000, layers=1, nodes=200, act=tanh | time=3.48s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=2, nodes=200, act=tanh | time=3.86s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=2, nodes=200, act=tanh | time=7.72s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=200, act=tanh | time=5.97s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=200, act=tanh | time=11.96s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=200, act=tanh | time=7.92s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=200, act=tanh | time=15.92s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=200, act=tanh | time=10.01s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=200, act=tanh | time=20.00s
# MSE: 1.160e-02 | LR=0.1, epochs=2000, layers=1, nodes=10, act=relu | time=0.94s
# MSE: 8.850e-03 | LR=0.1, epochs=2000, layers=1, nodes=10, act=relu | time=1.91s
# MSE: 8.102e-03 | LR=0.1, epochs=2000, layers=2, nodes=10, act=relu | time=1.23s
# MSE: 1.189e-02 | LR=0.1, epochs=2000, layers=2, nodes=10, act=relu | time=2.47s
# MSE: 8.847e-03 | LR=0.1, epochs=2000, layers=3, nodes=10, act=relu | time=1.46s
# MSE: 1.260e-02 | LR=0.1, epochs=2000, layers=3, nodes=10, act=relu | time=2.91s
# MSE: 1.260e-02 | LR=0.1, epochs=2000, layers=4, nodes=10, act=relu | time=1.65s
# MSE: 1.268e-02 | LR=0.1, epochs=2000, layers=4, nodes=10, act=relu | time=3.27s
# MSE: 8.834e-03 | LR=0.1, epochs=2000, layers=5, nodes=10, act=relu | time=1.83s
# MSE: 9.883e-03 | LR=0.1, epochs=2000, layers=5, nodes=10, act=relu | time=3.75s
# MSE: 1.189e-02 | LR=0.1, epochs=2000, layers=1, nodes=20, act=relu | time=1.02s
# MSE: 1.147e-02 | LR=0.1, epochs=2000, layers=1, nodes=20, act=relu | time=2.04s
# MSE: 8.515e-03 | LR=0.1, epochs=2000, layers=2, nodes=20, act=relu | time=1.27s
# MSE: 8.847e-03 | LR=0.1, epochs=2000, layers=2, nodes=20, act=relu | time=2.54s
# MSE: 1.189e-02 | LR=0.1, epochs=2000, layers=3, nodes=20, act=relu | time=1.46s
# MSE: 8.904e-03 | LR=0.1, epochs=2000, layers=3, nodes=20, act=relu | time=2.91s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=20, act=relu | time=1.66s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=20, act=relu | time=3.33s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=relu | time=1.98s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=relu | time=3.95s
# MSE: 8.807e-03 | LR=0.1, epochs=2000, layers=1, nodes=50, act=relu | time=1.08s
# MSE: 8.807e-03 | LR=0.1, epochs=2000, layers=1, nodes=50, act=relu | time=2.16s
# MSE: 1.258e-02 | LR=0.1, epochs=2000, layers=2, nodes=50, act=relu | time=1.64s
# MSE: 1.231e-02 | LR=0.1, epochs=2000, layers=2, nodes=50, act=relu | time=3.27s
# MSE: 1.187e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=relu | time=1.93s
# MSE: 1.147e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=relu | time=3.87s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=relu | time=2.31s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=relu | time=4.60s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=relu | time=2.63s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=relu | time=5.24s
# MSE: 1.189e-02 | LR=0.1, epochs=2000, layers=1, nodes=100, act=relu | time=1.18s
# MSE: 1.199e-02 | LR=0.1, epochs=2000, layers=1, nodes=100, act=relu | time=2.37s
# MSE: 1.188e-02 | LR=0.1, epochs=2000, layers=2, nodes=100, act=relu | time=2.01s
# MSE: 1.258e-02 | LR=0.1, epochs=2000, layers=2, nodes=100, act=relu | time=4.01s
# MSE: 1.365e-02 | LR=0.1, epochs=2000, layers=3, nodes=100, act=relu | time=2.27s
# MSE: 8.803e-03 | LR=0.1, epochs=2000, layers=3, nodes=100, act=relu | time=4.51s
# MSE: 9.452e-03 | LR=0.1, epochs=2000, layers=4, nodes=100, act=relu | time=2.75s
# MSE: 1.154e-02 | LR=0.1, epochs=2000, layers=4, nodes=100, act=relu | time=5.53s
# MSE: 8.901e-03 | LR=0.1, epochs=2000, layers=5, nodes=100, act=relu | time=3.23s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=relu | time=6.43s
# MSE: 1.379e-02 | LR=0.1, epochs=2000, layers=1, nodes=200, act=relu | time=1.19s
# MSE: 1.146e-02 | LR=0.1, epochs=2000, layers=1, nodes=200, act=relu | time=2.44s
# MSE: 8.667e-03 | LR=0.1, epochs=2000, layers=2, nodes=200, act=relu | time=2.99s
# MSE: 1.251e-02 | LR=0.1, epochs=2000, layers=2, nodes=200, act=relu | time=5.93s
# MSE: 7.786e-03 | LR=0.1, epochs=2000, layers=3, nodes=200, act=relu | time=4.41s
# MSE: 1.364e-02 | LR=0.1, epochs=2000, layers=3, nodes=200, act=relu | time=8.82s
# MSE: 4.878e-03 | LR=0.1, epochs=2000, layers=4, nodes=200, act=relu | time=5.87s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=200, act=relu | time=11.75s
# MSE: 4.102e-02 | LR=0.1, epochs=2000, layers=5, nodes=200, act=relu | time=7.36s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=200, act=relu | time=14.59s
# MSE: 1.342e-05 | LR=0.1, epochs=2000, layers=1, nodes=10, act=gelu | time=1.12s
# MSE: 7.137e-06 | LR=0.1, epochs=2000, layers=1, nodes=10, act=gelu | time=2.24s
# MSE: 2.096e-03 | LR=0.1, epochs=2000, layers=2, nodes=10, act=gelu | time=1.56s
# MSE: 6.751e-04 | LR=0.1, epochs=2000, layers=2, nodes=10, act=gelu | time=3.19s
# MSE: 1.189e-06 | LR=0.1, epochs=2000, layers=3, nodes=10, act=gelu | time=2.05s
# MSE: 3.883e-05 | LR=0.1, epochs=2000, layers=3, nodes=10, act=gelu | time=4.11s
# MSE: 1.758e-05 | LR=0.1, epochs=2000, layers=4, nodes=10, act=gelu | time=2.37s
# MSE: 1.642e-05 | LR=0.1, epochs=2000, layers=4, nodes=10, act=gelu | time=4.75s
# MSE: 6.182e-05 | LR=0.1, epochs=2000, layers=5, nodes=10, act=gelu | time=2.87s
# MSE: 2.758e-05 | LR=0.1, epochs=2000, layers=5, nodes=10, act=gelu | time=5.77s
# MSE: 1.619e-05 | LR=0.1, epochs=2000, layers=1, nodes=20, act=gelu | time=1.24s
# MSE: 4.025e-06 | LR=0.1, epochs=2000, layers=1, nodes=20, act=gelu | time=2.46s
# MSE: 5.830e-05 | LR=0.1, epochs=2000, layers=2, nodes=20, act=gelu | time=1.70s
# MSE: 1.478e-04 | LR=0.1, epochs=2000, layers=2, nodes=20, act=gelu | time=3.38s
# MSE: 2.680e-05 | LR=0.1, epochs=2000, layers=3, nodes=20, act=gelu | time=2.22s
# MSE: 3.476e-06 | LR=0.1, epochs=2000, layers=3, nodes=20, act=gelu | time=4.47s
# MSE: 1.222e-04 | LR=0.1, epochs=2000, layers=4, nodes=20, act=gelu | time=2.74s
# MSE: 4.266e-02 | LR=0.1, epochs=2000, layers=4, nodes=20, act=gelu | time=5.38s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=gelu | time=3.10s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=gelu | time=6.31s
# MSE: 2.350e-06 | LR=0.1, epochs=2000, layers=1, nodes=50, act=gelu | time=1.98s
# MSE: 2.070e-06 | LR=0.1, epochs=2000, layers=1, nodes=50, act=gelu | time=3.94s
# MSE: 2.847e-06 | LR=0.1, epochs=2000, layers=2, nodes=50, act=gelu | time=3.24s
# MSE: 7.362e-07 | LR=0.1, epochs=2000, layers=2, nodes=50, act=gelu | time=6.51s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=gelu | time=4.59s
# MSE: 4.307e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=gelu | time=9.23s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=gelu | time=5.71s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=gelu | time=11.41s
# MSE: 3.121e-07 | LR=0.1, epochs=2000, layers=5, nodes=50, act=gelu | time=6.96s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=gelu | time=13.87s
# MSE: 2.772e-06 | LR=0.1, epochs=2000, layers=1, nodes=100, act=gelu | time=2.61s
# MSE: 9.336e-07 | LR=0.1, epochs=2000, layers=1, nodes=100, act=gelu | time=5.26s
# MSE: 3.168e-06 | LR=0.1, epochs=2000, layers=2, nodes=100, act=gelu | time=4.70s
# MSE: 1.844e-05 | LR=0.1, epochs=2000, layers=2, nodes=100, act=gelu | time=9.44s
# MSE: 1.636e-05 | LR=0.1, epochs=2000, layers=3, nodes=100, act=gelu | time=6.63s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=100, act=gelu | time=13.22s
# MSE: 1.152e-04 | LR=0.1, epochs=2000, layers=4, nodes=100, act=gelu | time=8.68s
# MSE: 2.976e-01 | LR=0.1, epochs=2000, layers=4, nodes=100, act=gelu | time=17.21s
# MSE: 4.380e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=gelu | time=10.31s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=gelu | time=20.77s
# MSE: 5.382e-06 | LR=0.1, epochs=2000, layers=1, nodes=200, act=gelu | time=3.28s
# MSE: 1.079e-04 | LR=0.1, epochs=2000, layers=1, nodes=200, act=gelu | time=6.51s
# MSE: 1.943e-04 | LR=0.1, epochs=2000, layers=2, nodes=200, act=gelu | time=7.23s
# MSE: 7.502e-05 | LR=0.1, epochs=2000, layers=2, nodes=200, act=gelu | time=14.83s
# MSE: 4.109e-02 | LR=0.1, epochs=2000, layers=3, nodes=200, act=gelu | time=10.93s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=200, act=gelu | time=21.49s
# MSE: 2.452e-02 | LR=0.1, epochs=2000, layers=4, nodes=200, act=gelu | time=14.83s
# MSE: 1.977e-02 | LR=0.1, epochs=2000, layers=4, nodes=200, act=gelu | time=29.63s
# MSE: 3.554e+00 | LR=0.1, epochs=2000, layers=5, nodes=200, act=gelu | time=17.70s
# MSE: 2.453e+01 | LR=0.1, epochs=2000, layers=5, nodes=200, act=gelu | time=35.94s
# MSE: 6.797e-05 | LR=0.1, epochs=2000, layers=1, nodes=10, act=sigmoid | time=1.01s
# MSE: 5.661e-06 | LR=0.1, epochs=2000, layers=1, nodes=10, act=sigmoid | time=2.02s
# MSE: 2.596e-06 | LR=0.1, epochs=2000, layers=2, nodes=10, act=sigmoid | time=1.41s
# MSE: 3.833e-07 | LR=0.1, epochs=2000, layers=2, nodes=10, act=sigmoid | time=2.80s
# MSE: 5.980e-07 | LR=0.1, epochs=2000, layers=3, nodes=10, act=sigmoid | time=1.71s
# MSE: 3.209e-07 | LR=0.1, epochs=2000, layers=3, nodes=10, act=sigmoid | time=3.39s
# MSE: 5.081e-06 | LR=0.1, epochs=2000, layers=4, nodes=10, act=sigmoid | time=1.95s
# MSE: 6.239e-06 | LR=0.1, epochs=2000, layers=4, nodes=10, act=sigmoid | time=3.87s
# MSE: 3.716e-06 | LR=0.1, epochs=2000, layers=5, nodes=10, act=sigmoid | time=2.25s
# MSE: 2.052e-07 | LR=0.1, epochs=2000, layers=5, nodes=10, act=sigmoid | time=4.59s
# MSE: 1.962e-06 | LR=0.1, epochs=2000, layers=1, nodes=20, act=sigmoid | time=1.12s
# MSE: 1.144e-06 | LR=0.1, epochs=2000, layers=1, nodes=20, act=sigmoid | time=2.24s
# MSE: 3.631e-06 | LR=0.1, epochs=2000, layers=2, nodes=20, act=sigmoid | time=1.43s
# MSE: 6.894e-07 | LR=0.1, epochs=2000, layers=2, nodes=20, act=sigmoid | time=2.86s
# MSE: 2.477e-06 | LR=0.1, epochs=2000, layers=3, nodes=20, act=sigmoid | time=1.73s
# MSE: 1.395e-06 | LR=0.1, epochs=2000, layers=3, nodes=20, act=sigmoid | time=3.46s
# MSE: 9.252e-05 | LR=0.1, epochs=2000, layers=4, nodes=20, act=sigmoid | time=2.13s
# MSE: 1.347e-06 | LR=0.1, epochs=2000, layers=4, nodes=20, act=sigmoid | time=4.26s
# MSE: 1.113e-04 | LR=0.1, epochs=2000, layers=5, nodes=20, act=sigmoid | time=2.47s
# MSE: 3.841e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=sigmoid | time=4.86s
# MSE: 1.969e-06 | LR=0.1, epochs=2000, layers=1, nodes=50, act=sigmoid | time=1.14s
# MSE: 5.165e-07 | LR=0.1, epochs=2000, layers=1, nodes=50, act=sigmoid | time=2.31s
# MSE: 1.825e-05 | LR=0.1, epochs=2000, layers=2, nodes=50, act=sigmoid | time=1.87s
# MSE: 3.343e-06 | LR=0.1, epochs=2000, layers=2, nodes=50, act=sigmoid | time=3.79s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=sigmoid | time=2.39s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=sigmoid | time=4.77s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=sigmoid | time=2.84s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=sigmoid | time=5.69s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=sigmoid | time=3.50s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=sigmoid | time=6.91s
# MSE: 2.366e-06 | LR=0.1, epochs=2000, layers=1, nodes=100, act=sigmoid | time=1.29s
# MSE: 1.393e-07 | LR=0.1, epochs=2000, layers=1, nodes=100, act=sigmoid | time=2.58s
# MSE: 2.837e-05 | LR=0.1, epochs=2000, layers=2, nodes=100, act=sigmoid | time=2.20s
# MSE: 2.841e-06 | LR=0.1, epochs=2000, layers=2, nodes=100, act=sigmoid | time=4.47s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=100, act=sigmoid | time=3.16s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=100, act=sigmoid | time=6.28s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=100, act=sigmoid | time=3.68s
# MSE: 4.315e-02 | LR=0.1, epochs=2000, layers=4, nodes=100, act=sigmoid | time=7.53s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=sigmoid | time=4.43s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=100, act=sigmoid | time=8.80s
# MSE: 4.610e-06 | LR=0.1, epochs=2000, layers=1, nodes=200, act=sigmoid | time=1.50s
# MSE: 7.149e-07 | LR=0.1, epochs=2000, layers=1, nodes=200, act=sigmoid | time=2.98s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=2, nodes=200, act=sigmoid | time=3.93s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=2, nodes=200, act=sigmoid | time=7.82s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=200, act=sigmoid | time=5.76s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=3, nodes=200, act=sigmoid | time=11.52s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=200, act=sigmoid | time=7.74s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=4, nodes=200, act=sigmoid | time=15.49s
# MSE: 4.314e-02 | LR=0.1, epochs=2000, layers=5, nodes=200, act=sigmoid | time=9.69s
# MSE: 4.115e-02 | LR=0.1, epochs=2000, layers=5, nodes=200, act=sigmoid | time=19.42s
# MSE: 8.847e-03 | LR=0.1, epochs=2000, layers=1, nodes=10, act=leaky | time=0.98s
# MSE: 1.202e-02 | LR=0.1, epochs=2000, layers=1, nodes=10, act=leaky | time=1.95s
# MSE: 6.970e-03 | LR=0.1, epochs=2000, layers=2, nodes=10, act=leaky | time=1.19s
# MSE: 8.533e-03 | LR=0.1, epochs=2000, layers=2, nodes=10, act=leaky | time=2.37s
# MSE: 1.365e-02 | LR=0.1, epochs=2000, layers=3, nodes=10, act=leaky | time=1.36s
# MSE: 8.125e-03 | LR=0.1, epochs=2000, layers=3, nodes=10, act=leaky | time=2.73s
# MSE: 1.620e-02 | LR=0.1, epochs=2000, layers=4, nodes=10, act=leaky | time=1.58s
# MSE: 8.847e-03 | LR=0.1, epochs=2000, layers=4, nodes=10, act=leaky | time=3.20s
# MSE: 7.235e-03 | LR=0.1, epochs=2000, layers=5, nodes=10, act=leaky | time=1.86s
# MSE: 8.847e-03 | LR=0.1, epochs=2000, layers=5, nodes=10, act=leaky | time=3.70s
# MSE: 1.189e-02 | LR=0.1, epochs=2000, layers=1, nodes=20, act=leaky | time=1.03s
# MSE: 1.156e-02 | LR=0.1, epochs=2000, layers=1, nodes=20, act=leaky | time=2.01s
# MSE: 1.190e-02 | LR=0.1, epochs=2000, layers=2, nodes=20, act=leaky | time=1.25s
# MSE: 8.399e-03 | LR=0.1, epochs=2000, layers=2, nodes=20, act=leaky | time=2.50s
# MSE: 1.919e-02 | LR=0.1, epochs=2000, layers=3, nodes=20, act=leaky | time=1.49s
# MSE: 8.631e-03 | LR=0.1, epochs=2000, layers=3, nodes=20, act=leaky | time=2.98s
# MSE: 2.263e-02 | LR=0.1, epochs=2000, layers=4, nodes=20, act=leaky | time=1.77s
# MSE: 6.794e-03 | LR=0.1, epochs=2000, layers=4, nodes=20, act=leaky | time=3.54s
# MSE: 7.687e-03 | LR=0.1, epochs=2000, layers=5, nodes=20, act=leaky | time=1.97s
# MSE: 8.650e-02 | LR=0.1, epochs=2000, layers=5, nodes=20, act=leaky | time=3.91s
# MSE: 4.719e-03 | LR=0.1, epochs=2000, layers=1, nodes=50, act=leaky | time=1.06s
# MSE: 1.190e-02 | LR=0.1, epochs=2000, layers=1, nodes=50, act=leaky | time=2.11s
# MSE: 1.138e-02 | LR=0.1, epochs=2000, layers=2, nodes=50, act=leaky | time=1.65s
# MSE: 1.049e-02 | LR=0.1, epochs=2000, layers=2, nodes=50, act=leaky | time=3.28s
# MSE: 2.094e-02 | LR=0.1, epochs=2000, layers=3, nodes=50, act=leaky | time=1.95s
# MSE: 8.847e-03 | LR=0.1, epochs=2000, layers=3, nodes=50, act=leaky | time=3.90s
# MSE: 2.775e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=leaky | time=2.30s
# MSE: 1.393e-02 | LR=0.1, epochs=2000, layers=4, nodes=50, act=leaky | time=4.71s
# MSE: 4.248e-02 | LR=0.1, epochs=2000, layers=5, nodes=50, act=leaky | time=2.79s
# MSE: 6.941e-03 | LR=0.1, epochs=2000, layers=5, nodes=50, act=leaky | time=5.53s
# MSE: 6.220e-03 | LR=0.1, epochs=2000, layers=1, nodes=100, act=leaky | time=1.20s
# MSE: 1.211e-02 | LR=0.1, epochs=2000, layers=1, nodes=100, act=leaky | time=2.38s
# MSE: 7.391e-03 | LR=0.1, epochs=2000, layers=2, nodes=100, act=leaky | time=2.01s
# MSE: 6.398e-03 | LR=0.1, epochs=2000, layers=2, nodes=100, act=leaky | time=4.00s
# MSE: 3.493e-03 | LR=0.1, epochs=2000, layers=3, nodes=100, act=leaky | time=2.34s
# MSE: 1.121e-02 | LR=0.1, epochs=2000, layers=3, nodes=100, act=leaky | time=4.69s
# MSE: 2.229e+00 | LR=0.1, epochs=2000, layers=4, nodes=100, act=leaky | time=2.80s
# MSE: 1.343e+00 | LR=0.1, epochs=2000, layers=4, nodes=100, act=leaky | time=5.58s
# MSE: 9.099e-03 | LR=0.1, epochs=2000, layers=5, nodes=100, act=leaky | time=3.25s
# MSE: 1.771e-03 | LR=0.1, epochs=2000, layers=5, nodes=100, act=leaky | time=6.54s
# MSE: 5.466e-03 | LR=0.1, epochs=2000, layers=1, nodes=200, act=leaky | time=1.29s
# MSE: 5.087e-03 | LR=0.1, epochs=2000, layers=1, nodes=200, act=leaky | time=2.54s
# ...
# MSE: 4.940e-03 | LR=0.0001, epochs=5000, layers=2, nodes=20, act=relu | time=3.17s
# MSE: 1.937e-03 | LR=0.0001, epochs=5000, layers=2, nodes=20, act=relu | time=6.27s
# MSE: 1.767e-03 | LR=0.0001, epochs=5000, layers=3, nodes=20, act=relu | time=3.62s
# MSE: 4.459e-03 | LR=0.0001, epochs=5000, layers=3, nodes=20, act=relu | time=7.42s
# MSE: 4.023e-03 | LR=0.0001, epochs=5000, layers=4, nodes=20, act=relu | time=4.28s
# MSE: 3.777e-03 | LR=0.0001, epochs=5000, layers=4, nodes=20, act=relu | time=8.51s
# MSE: 3.811e-03 | LR=0.0001, epochs=5000, layers=5, nodes=20, act=relu | time=4.97s
# MSE: 7.333e-03 | LR=0.0001, epochs=5000, layers=5, nodes=20, act=relu | time=9.74s
# MSE: 1.180e-02 | LR=0.0001, epochs=5000, layers=1, nodes=50, act=relu | time=2.60s
# MSE: 5.214e-03 | LR=0.0001, epochs=5000, layers=1, nodes=50, act=relu | time=5.26s
# MSE: 6.967e-03 | LR=0.0001, epochs=5000, layers=2, nodes=50, act=relu | time=4.24s
# MSE: 2.731e-03 | LR=0.0001, epochs=5000, layers=2, nodes=50, act=relu | time=8.38s
# MSE: 1.821e-03 | LR=0.0001, epochs=5000, layers=3, nodes=50, act=relu | time=4.87s
# MSE: 3.301e-03 | LR=0.0001, epochs=5000, layers=3, nodes=50, act=relu | time=9.72s
# MSE: 2.285e-03 | LR=0.0001, epochs=5000, layers=4, nodes=50, act=relu | time=5.80s
# MSE: 7.465e-04 | LR=0.0001, epochs=5000, layers=4, nodes=50, act=relu | time=11.46s
# MSE: 1.870e-03 | LR=0.0001, epochs=5000, layers=5, nodes=50, act=relu | time=6.68s
# MSE: 6.256e-03 | LR=0.0001, epochs=5000, layers=5, nodes=50, act=relu | time=13.35s
# MSE: 9.115e-03 | LR=0.0001, epochs=5000, layers=1, nodes=100, act=relu | time=3.05s
# MSE: 5.143e-03 | LR=0.0001, epochs=5000, layers=1, nodes=100, act=relu | time=6.03s
# MSE: 2.060e-03 | LR=0.0001, epochs=5000, layers=2, nodes=100, act=relu | time=4.95s
# MSE: 1.689e-03 | LR=0.0001, epochs=5000, layers=2, nodes=100, act=relu | time=9.97s
# MSE: 4.122e-03 | LR=0.0001, epochs=5000, layers=3, nodes=100, act=relu | time=5.79s
# MSE: 1.335e-03 | LR=0.0001, epochs=5000, layers=3, nodes=100, act=relu | time=11.48s
# MSE: 8.729e-04 | LR=0.0001, epochs=5000, layers=4, nodes=100, act=relu | time=6.96s
# MSE: 1.375e-03 | LR=0.0001, epochs=5000, layers=4, nodes=100, act=relu | time=13.94s
# MSE: 1.178e-03 | LR=0.0001, epochs=5000, layers=5, nodes=100, act=relu | time=8.21s
# MSE: 1.318e-03 | LR=0.0001, epochs=5000, layers=5, nodes=100, act=relu | time=16.43s
# MSE: 7.905e-03 | LR=0.0001, epochs=5000, layers=1, nodes=200, act=relu | time=3.12s
# MSE: 4.221e-03 | LR=0.0001, epochs=5000, layers=1, nodes=200, act=relu | time=6.25s
# MSE: 2.488e-03 | LR=0.0001, epochs=5000, layers=2, nodes=200, act=relu | time=7.50s
# MSE: 1.836e-03 | LR=0.0001, epochs=5000, layers=2, nodes=200, act=relu | time=14.90s
# MSE: 2.937e-03 | LR=0.0001, epochs=5000, layers=3, nodes=200, act=relu | time=11.17s
# MSE: 2.306e-03 | LR=0.0001, epochs=5000, layers=3, nodes=200, act=relu | time=22.44s
# MSE: 3.131e-03 | LR=0.0001, epochs=5000, layers=4, nodes=200, act=relu | time=15.12s
# MSE: 3.059e-03 | LR=0.0001, epochs=5000, layers=4, nodes=200, act=relu | time=30.33s
# MSE: 2.325e-03 | LR=0.0001, epochs=5000, layers=5, nodes=200, act=relu | time=18.41s
# MSE: 1.749e-03 | LR=0.0001, epochs=5000, layers=5, nodes=200, act=relu | time=36.98s
# MSE: 3.345e-02 | LR=0.0001, epochs=5000, layers=1, nodes=10, act=gelu | time=2.84s
# MSE: 1.262e-02 | LR=0.0001, epochs=5000, layers=1, nodes=10, act=gelu | time=5.61s
# MSE: 1.229e-02 | LR=0.0001, epochs=5000, layers=2, nodes=10, act=gelu | time=3.89s
# MSE: 1.718e-03 | LR=0.0001, epochs=5000, layers=2, nodes=10, act=gelu | time=7.83s
# MSE: 2.087e-03 | LR=0.0001, epochs=5000, layers=3, nodes=10, act=gelu | time=4.79s
# MSE: 1.281e-05 | LR=0.0001, epochs=5000, layers=3, nodes=10, act=gelu | time=9.85s
# MSE: 6.150e-04 | LR=0.0001, epochs=5000, layers=4, nodes=10, act=gelu | time=5.92s
# MSE: 1.288e-06 | LR=0.0001, epochs=5000, layers=4, nodes=10, act=gelu | time=12.02s
# MSE: 2.226e-04 | LR=0.0001, epochs=5000, layers=5, nodes=10, act=gelu | time=7.11s
# MSE: 3.048e-07 | LR=0.0001, epochs=5000, layers=5, nodes=10, act=gelu | time=14.08s
# MSE: 2.957e-02 | LR=0.0001, epochs=5000, layers=1, nodes=20, act=gelu | time=3.20s
# MSE: 9.934e-03 | LR=0.0001, epochs=5000, layers=1, nodes=20, act=gelu | time=6.27s
# MSE: 3.028e-03 | LR=0.0001, epochs=5000, layers=2, nodes=20, act=gelu | time=4.31s
# MSE: 5.855e-05 | LR=0.0001, epochs=5000, layers=2, nodes=20, act=gelu | time=8.85s
# MSE: 2.174e-04 | LR=0.0001, epochs=5000, layers=3, nodes=20, act=gelu | time=5.62s
# MSE: 5.027e-07 | LR=0.0001, epochs=5000, layers=3, nodes=20, act=gelu | time=11.54s
# MSE: 3.972e-05 | LR=0.0001, epochs=5000, layers=4, nodes=20, act=gelu | time=7.10s
# MSE: 6.348e-08 | LR=0.0001, epochs=5000, layers=4, nodes=20, act=gelu | time=14.12s
# MSE: 9.945e-06 | LR=0.0001, epochs=5000, layers=5, nodes=20, act=gelu | time=8.35s
# MSE: 1.212e-07 | LR=0.0001, epochs=5000, layers=5, nodes=20, act=gelu | time=16.71s
# MSE: 1.371e-02 | LR=0.0001, epochs=5000, layers=1, nodes=50, act=gelu | time=4.93s
# MSE: 5.853e-03 | LR=0.0001, epochs=5000, layers=1, nodes=50, act=gelu | time=9.76s
# MSE: 2.449e-04 | LR=0.0001, epochs=5000, layers=2, nodes=50, act=gelu | time=8.13s
# MSE: 1.596e-06 | LR=0.0001, epochs=5000, layers=2, nodes=50, act=gelu | time=16.26s
# MSE: 9.179e-06 | LR=0.0001, epochs=5000, layers=3, nodes=50, act=gelu | time=11.17s
# MSE: 7.549e-08 | LR=0.0001, epochs=5000, layers=3, nodes=50, act=gelu | time=22.59s
# MSE: 7.334e-07 | LR=0.0001, epochs=5000, layers=4, nodes=50, act=gelu | time=14.32s
# MSE: 3.688e-08 | LR=0.0001, epochs=5000, layers=4, nodes=50, act=gelu | time=28.64s
# MSE: 6.923e-07 | LR=0.0001, epochs=5000, layers=5, nodes=50, act=gelu | time=17.59s
# MSE: 2.681e-08 | LR=0.0001, epochs=5000, layers=5, nodes=50, act=gelu | time=35.25s
# MSE: 1.105e-02 | LR=0.0001, epochs=5000, layers=1, nodes=100, act=gelu | time=6.53s
# MSE: 2.985e-03 | LR=0.0001, epochs=5000, layers=1, nodes=100, act=gelu | time=13.20s
# MSE: 2.952e-05 | LR=0.0001, epochs=5000, layers=2, nodes=100, act=gelu | time=12.12s
# MSE: 7.446e-08 | LR=0.0001, epochs=5000, layers=2, nodes=100, act=gelu | time=24.13s
# MSE: 1.217e-06 | LR=0.0001, epochs=5000, layers=3, nodes=100, act=gelu | time=17.11s
# MSE: 3.952e-08 | LR=0.0001, epochs=5000, layers=3, nodes=100, act=gelu | time=34.37s
# MSE: 2.154e-07 | LR=0.0001, epochs=5000, layers=4, nodes=100, act=gelu | time=22.01s
# MSE: 3.242e-08 | LR=0.0001, epochs=5000, layers=4, nodes=100, act=gelu | time=44.12s
# MSE: 9.689e-08 | LR=0.0001, epochs=5000, layers=5, nodes=100, act=gelu | time=26.34s
# MSE: 3.101e-08 | LR=0.0001, epochs=5000, layers=5, nodes=100, act=gelu | time=53.99s
# MSE: 7.733e-03 | LR=0.0001, epochs=5000, layers=1, nodes=200, act=gelu | time=8.39s
# MSE: 1.561e-03 | LR=0.0001, epochs=5000, layers=1, nodes=200, act=gelu | time=16.71s
# MSE: 9.736e-06 | LR=0.0001, epochs=5000, layers=2, nodes=200, act=gelu | time=17.95s
# MSE: 8.870e-08 | LR=0.0001, epochs=5000, layers=2, nodes=200, act=gelu | time=36.04s
# MSE: 3.992e-07 | LR=0.0001, epochs=5000, layers=3, nodes=200, act=gelu | time=27.27s
# MSE: 1.733e-07 | LR=0.0001, epochs=5000, layers=3, nodes=200, act=gelu | time=54.70s
# MSE: 1.216e-07 | LR=0.0001, epochs=5000, layers=4, nodes=200, act=gelu | time=36.87s
# MSE: 5.174e-08 | LR=0.0001, epochs=5000, layers=4, nodes=200, act=gelu | time=73.11s
# MSE: 2.179e-07 | LR=0.0001, epochs=5000, layers=5, nodes=200, act=gelu | time=45.37s
# MSE: 1.013e-08 | LR=0.0001, epochs=5000, layers=5, nodes=200, act=gelu | time=91.21s
# MSE: 3.949e-02 | LR=0.0001, epochs=5000, layers=1, nodes=10, act=sigmoid | time=2.71s
# MSE: 3.067e-02 | LR=0.0001, epochs=5000, layers=1, nodes=10, act=sigmoid | time=5.38s
# MSE: 4.029e-02 | LR=0.0001, epochs=5000, layers=2, nodes=10, act=sigmoid | time=3.41s
# MSE: 2.038e-02 | LR=0.0001, epochs=5000, layers=2, nodes=10, act=sigmoid | time=6.86s
# MSE: 4.310e-02 | LR=0.0001, epochs=5000, layers=3, nodes=10, act=sigmoid | time=4.22s
# MSE: 2.220e-02 | LR=0.0001, epochs=5000, layers=3, nodes=10, act=sigmoid | time=8.29s
# MSE: 4.287e-02 | LR=0.0001, epochs=5000, layers=4, nodes=10, act=sigmoid | time=5.12s
# MSE: 1.784e-02 | LR=0.0001, epochs=5000, layers=4, nodes=10, act=sigmoid | time=9.96s
# MSE: 4.314e-02 | LR=0.0001, epochs=5000, layers=5, nodes=10, act=sigmoid | time=5.83s
# MSE: 1.767e-02 | LR=0.0001, epochs=5000, layers=5, nodes=10, act=sigmoid | time=11.51s
# MSE: 3.529e-02 | LR=0.0001, epochs=5000, layers=1, nodes=20, act=sigmoid | time=2.71s
# MSE: 2.012e-02 | LR=0.0001, epochs=5000, layers=1, nodes=20, act=sigmoid | time=5.45s
# MSE: 3.535e-02 | LR=0.0001, epochs=5000, layers=2, nodes=20, act=sigmoid | time=3.70s
# MSE: 1.087e-02 | LR=0.0001, epochs=5000, layers=2, nodes=20, act=sigmoid | time=7.54s
# MSE: 4.169e-02 | LR=0.0001, epochs=5000, layers=3, nodes=20, act=sigmoid | time=4.48s
# MSE: 1.205e-02 | LR=0.0001, epochs=5000, layers=3, nodes=20, act=sigmoid | time=8.80s
# MSE: 4.143e-02 | LR=0.0001, epochs=5000, layers=4, nodes=20, act=sigmoid | time=5.38s
# MSE: 1.210e-02 | LR=0.0001, epochs=5000, layers=4, nodes=20, act=sigmoid | time=10.67s
# MSE: 4.265e-02 | LR=0.0001, epochs=5000, layers=5, nodes=20, act=sigmoid | time=6.36s
# MSE: 1.166e-02 | LR=0.0001, epochs=5000, layers=5, nodes=20, act=sigmoid | time=12.74s
# MSE: 3.245e-02 | LR=0.0001, epochs=5000, layers=1, nodes=50, act=sigmoid | time=2.94s
# MSE: 1.267e-02 | LR=0.0001, epochs=5000, layers=1, nodes=50, act=sigmoid | time=5.81s
# MSE: 1.323e-02 | LR=0.0001, epochs=5000, layers=2, nodes=50, act=sigmoid | time=4.63s
# MSE: 1.860e-03 | LR=0.0001, epochs=5000, layers=2, nodes=50, act=sigmoid | time=9.40s
# MSE: 4.302e-03 | LR=0.0001, epochs=5000, layers=3, nodes=50, act=sigmoid | time=5.80s
# MSE: 8.774e-05 | LR=0.0001, epochs=5000, layers=3, nodes=50, act=sigmoid | time=11.74s
# MSE: 5.937e-03 | LR=0.0001, epochs=5000, layers=4, nodes=50, act=sigmoid | time=7.24s
# MSE: 3.062e-04 | LR=0.0001, epochs=5000, layers=4, nodes=50, act=sigmoid | time=14.37s
# MSE: 8.899e-04 | LR=0.0001, epochs=5000, layers=5, nodes=50, act=sigmoid | time=8.46s
# MSE: 7.387e-05 | LR=0.0001, epochs=5000, layers=5, nodes=50, act=sigmoid | time=16.92s
# MSE: 2.017e-02 | LR=0.0001, epochs=5000, layers=1, nodes=100, act=sigmoid | time=3.29s
# MSE: 9.791e-03 | LR=0.0001, epochs=5000, layers=1, nodes=100, act=sigmoid | time=6.58s
# MSE: 3.694e-03 | LR=0.0001, epochs=5000, layers=2, nodes=100, act=sigmoid | time=5.83s
# MSE: 1.926e-05 | LR=0.0001, epochs=5000, layers=2, nodes=100, act=sigmoid | time=11.47s
# MSE: 8.650e-04 | LR=0.0001, epochs=5000, layers=3, nodes=100, act=sigmoid | time=7.90s
# MSE: 3.900e-06 | LR=0.0001, epochs=5000, layers=3, nodes=100, act=sigmoid | time=15.62s
# MSE: 6.003e-04 | LR=0.0001, epochs=5000, layers=4, nodes=100, act=sigmoid | time=9.32s
# MSE: 7.420e-06 | LR=0.0001, epochs=5000, layers=4, nodes=100, act=sigmoid | time=18.55s
# MSE: 1.252e-03 | LR=0.0001, epochs=5000, layers=5, nodes=100, act=sigmoid | time=11.04s
# MSE: 1.107e-05 | LR=0.0001, epochs=5000, layers=5, nodes=100, act=sigmoid | time=22.18s
# MSE: 1.275e-02 | LR=0.0001, epochs=5000, layers=1, nodes=200, act=sigmoid | time=3.64s
# MSE: 7.421e-03 | LR=0.0001, epochs=5000, layers=1, nodes=200, act=sigmoid | time=7.46s
# MSE: 3.005e-04 | LR=0.0001, epochs=5000, layers=2, nodes=200, act=sigmoid | time=9.89s
# MSE: 1.354e-06 | LR=0.0001, epochs=5000, layers=2, nodes=200, act=sigmoid | time=19.72s
# MSE: 1.553e-04 | LR=0.0001, epochs=5000, layers=3, nodes=200, act=sigmoid | time=14.71s
# MSE: 9.927e-07 | LR=0.0001, epochs=5000, layers=3, nodes=200, act=sigmoid | time=29.10s
# MSE: 1.083e-04 | LR=0.0001, epochs=5000, layers=4, nodes=200, act=sigmoid | time=19.62s
# MSE: 1.227e-06 | LR=0.0001, epochs=5000, layers=4, nodes=200, act=sigmoid | time=39.43s
# MSE: 6.015e-05 | LR=0.0001, epochs=5000, layers=5, nodes=200, act=sigmoid | time=24.81s
# MSE: 2.617e-06 | LR=0.0001, epochs=5000, layers=5, nodes=200, act=sigmoid | time=48.89s
# MSE: 4.322e-02 | LR=0.0001, epochs=5000, layers=1, nodes=10, act=leaky | time=2.42s
# MSE: 2.411e-02 | LR=0.0001, epochs=5000, layers=1, nodes=10, act=leaky | time=4.85s
# MSE: 1.234e-02 | LR=0.0001, epochs=5000, layers=2, nodes=10, act=leaky | time=2.97s
# MSE: 5.900e-03 | LR=0.0001, epochs=5000, layers=2, nodes=10, act=leaky | time=5.89s
# MSE: 8.999e-03 | LR=0.0001, epochs=5000, layers=3, nodes=10, act=leaky | time=3.56s
# MSE: 8.108e-03 | LR=0.0001, epochs=5000, layers=3, nodes=10, act=leaky | time=7.14s
# MSE: 7.402e-03 | LR=0.0001, epochs=5000, layers=4, nodes=10, act=leaky | time=3.97s
# MSE: 6.156e-03 | LR=0.0001, epochs=5000, layers=4, nodes=10, act=leaky | time=8.15s
# MSE: 3.954e-03 | LR=0.0001, epochs=5000, layers=5, nodes=10, act=leaky | time=4.58s
# MSE: 2.931e-03 | LR=0.0001, epochs=5000, layers=5, nodes=10, act=leaky | time=9.22s
# MSE: 2.165e-02 | LR=0.0001, epochs=5000, layers=1, nodes=20, act=leaky | time=2.48s
# MSE: 7.846e-03 | LR=0.0001, epochs=5000, layers=1, nodes=20, act=leaky | time=4.96s
# MSE: 7.496e-03 | LR=0.0001, epochs=5000, layers=2, nodes=20, act=leaky | time=3.22s
# MSE: 3.762e-03 | LR=0.0001, epochs=5000, layers=2, nodes=20, act=leaky | time=6.51s
# MSE: 2.041e-03 | LR=0.0001, epochs=5000, layers=3, nodes=20, act=leaky | time=3.90s
# MSE: 9.586e-04 | LR=0.0001, epochs=5000, layers=3, nodes=20, act=leaky | time=7.98s
# MSE: 2.495e-03 | LR=0.0001, epochs=5000, layers=4, nodes=20, act=leaky | time=4.40s
# MSE: 2.876e-03 | LR=0.0001, epochs=5000, layers=4, nodes=20, act=leaky | time=8.62s
# MSE: 2.240e-03 | LR=0.0001, epochs=5000, layers=5, nodes=20, act=leaky | time=4.94s
# MSE: 5.741e-03 | LR=0.0001, epochs=5000, layers=5, nodes=20, act=leaky | time=9.82s
# MSE: 1.035e-02 | LR=0.0001, epochs=5000, layers=1, nodes=50, act=leaky | time=2.64s
# MSE: 5.205e-03 | LR=0.0001, epochs=5000, layers=1, nodes=50, act=leaky | time=5.38s
# MSE: 6.039e-03 | LR=0.0001, epochs=5000, layers=2, nodes=50, act=leaky | time=4.13s
# MSE: 2.861e-03 | LR=0.0001, epochs=5000, layers=2, nodes=50, act=leaky | time=8.22s
# MSE: 4.517e-04 | LR=0.0001, epochs=5000, layers=3, nodes=50, act=leaky | time=4.89s
# MSE: 9.763e-04 | LR=0.0001, epochs=5000, layers=3, nodes=50, act=leaky | time=9.72s
# MSE: 1.543e-03 | LR=0.0001, epochs=5000, layers=4, nodes=50, act=leaky | time=5.68s
# MSE: 4.664e-04 | LR=0.0001, epochs=5000, layers=4, nodes=50, act=leaky | time=11.31s
# MSE: 6.853e-04 | LR=0.0001, epochs=5000, layers=5, nodes=50, act=leaky | time=6.72s
# MSE: 1.589e-03 | LR=0.0001, epochs=5000, layers=5, nodes=50, act=leaky | time=13.32s
# MSE: 7.748e-03 | LR=0.0001, epochs=5000, layers=1, nodes=100, act=leaky | time=3.01s
# MSE: 3.838e-03 | LR=0.0001, epochs=5000, layers=1, nodes=100, act=leaky | time=5.94s
# MSE: 2.965e-03 | LR=0.0001, epochs=5000, layers=2, nodes=100, act=leaky | time=4.99s
# MSE: 1.781e-03 | LR=0.0001, epochs=5000, layers=2, nodes=100, act=leaky | time=10.09s
# MSE: 2.854e-03 | LR=0.0001, epochs=5000, layers=3, nodes=100, act=leaky | time=5.78s
# MSE: 2.198e-03 | LR=0.0001, epochs=5000, layers=3, nodes=100, act=leaky | time=11.77s
# MSE: 2.365e-03 | LR=0.0001, epochs=5000, layers=4, nodes=100, act=leaky | time=7.00s
# MSE: 1.525e-03 | LR=0.0001, epochs=5000, layers=4, nodes=100, act=leaky | time=13.97s
# MSE: 3.041e-03 | LR=0.0001, epochs=5000, layers=5, nodes=100, act=leaky | time=8.19s
# MSE: 1.528e-03 | LR=0.0001, epochs=5000, layers=5, nodes=100, act=leaky | time=16.33s
# MSE: 6.159e-03 | LR=0.0001, epochs=5000, layers=1, nodes=200, act=leaky | time=3.14s
# MSE: 5.190e-03 | LR=0.0001, epochs=5000, layers=1, nodes=200, act=leaky | time=6.22s
# MSE: 2.960e-03 | LR=0.0001, epochs=5000, layers=2, nodes=200, act=leaky | time=7.51s
# MSE: 1.955e-03 | LR=0.0001, epochs=5000, layers=2, nodes=200, act=leaky | time=15.02s
# MSE: 3.682e-03 | LR=0.0001, epochs=5000, layers=3, nodes=200, act=leaky | time=11.18s
# MSE: 2.829e-03 | LR=0.0001, epochs=5000, layers=3, nodes=200, act=leaky | time=22.27s
# MSE: 2.272e-03 | LR=0.0001, epochs=5000, layers=4, nodes=200, act=leaky | time=14.86s
# MSE: 2.566e-03 | LR=0.0001, epochs=5000, layers=4, nodes=200, act=leaky | time=29.39s
# MSE: 2.487e-03 | LR=0.0001, epochs=5000, layers=5, nodes=200, act=leaky | time=18.18s
# MSE: 4.356e-03 | LR=0.0001, epochs=5000, layers=5, nodes=200, act=leaky | time=36.50s
